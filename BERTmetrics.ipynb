# %%
# !pip install nltk
# !pip install contractions
# !pip install contractions pyspellchecker
# !pip install transformers
# !pip install datasets
# !pip install pandas
# !pip install scikit-learn
# !pip install seaborn
# !pip install matplotlib
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.6)
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Downloading anyascii-0.3.2-py3-none-any.whl.metadata (1.5 kB)
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (13 kB)
# Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 23.5 MB/s eta 0:00:00
# Downloading pyahocorasick-2.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 11.4 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.2 contractions-0.1.73 pyahocorasick-2.1.0 textsearch-0.0.24
# Requirement already satisfied: contractions in /usr/local/lib/python3.10/dist-packages (0.1.73)
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.8.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: textsearch>=0.0.21 in /usr/local/lib/python3.10/dist-packages (from contractions) (0.0.24)
# Requirement already satisfied: anyascii in /usr/local/lib/python3.10/dist-packages (from textsearch>=0.0.21->contractions) (0.3.2)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.10/dist-packages (from textsearch>=0.0.21->contractions) (2.1.0)
# Downloading pyspellchecker-0.8.1-py3-none-any.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 45.1 MB/s eta 0:00:00
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.8.1
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.6)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.9)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.26.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 15.9 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.1 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 13.5 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.6 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 14.0 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import re
import pandas as pd
from contractions import fix
import nltk
from contractions import fix
from spellchecker import SpellChecker
nltk.download('punkt')
from nltk.tokenize import word_tokenize
import os
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load the dataset with unique column names
df = pd.read_csv('/content/drive/MyDrive/BERT/combined_output.csv', names=['sentence', 'label'], header=0)

# Check for duplicate column names
if df.columns.duplicated().any():
    df.columns = pd.Index([f"{col}_{i}" if i > 0 else col for i, col in enumerate(df.columns)])

# Initialize the spellchecker
spell = SpellChecker()

# Function for cleaning text
def preprocess_text(text):
    # 1. Transform to lowercase
    text = text.lower()

    # 2. Remove unimportant data: links, usernames, hashtags, digits, punctuation, emojis
    text = re.sub(r'http\S+|www\S+|@\w+|#\w+|\d+|[^\w\s]|[^\x00-\x7F]+', '', text)

    return text

# Apply preprocessing to the 'sentence' column
df['sentence'] = df['sentence'].apply(preprocess_text)

# Save the preprocessed dataset
df.to_csv('/content/drive/MyDrive/BERT/preprocessed_dataset.csv', index=False, encoding='utf-8')

print("Preprocessing complete. The dataset has been saved as 'preprocessed_dataset.csv'.")
# Out:
# Preprocessing complete. The dataset has been saved as 'preprocessed_dataset.csv'.

# %%
import torch
from transformers import BertForSequenceClassification, BertTokenizer, Trainer, TrainingArguments
import pandas as pd
from datasets import Dataset
from sklearn.model_selection import train_test_split
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from datasets import load_dataset
from sklearn.metrics import confusion_matrix, classification_report
import torch
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (2.0.0)

# %%
# Load dataset from a single CSV file and split
df = pd.read_csv('/content/drive/MyDrive/BERT/preprocessed_dataset.csv')  # Adjust this path as needed
train_df, temp_df = train_test_split(df, test_size=0.2, stratify=df['label'], random_state=42)  # 80% train
val_df, test_df = train_test_split(temp_df, test_size=0.5, stratify=temp_df['label'], random_state=42)  # Split temp (10% val, 10% test)

# Convert pandas DataFrames to HuggingFace datasets
train_dataset = Dataset.from_pandas(train_df)
val_dataset = Dataset.from_pandas(val_df)
test_dataset = Dataset.from_pandas(test_df)

# Load pre-trained BERT tokenizer and model for sequence classification (2 output classes)
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)

# Tokenization function for the dataset
def tokenize_function(examples):
    return tokenizer(examples['sentence'], padding='max_length', max_length=128, truncation=True)

# Tokenize datasets
train_dataset = train_dataset.map(tokenize_function, batched=True)
val_dataset = val_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)

# Set format for PyTorch tensors
train_dataset.set_format('torch', columns=['input_ids', 'attention_mask', 'label'])
val_dataset.set_format('torch', columns=['input_ids', 'attention_mask', 'label'])
test_dataset.set_format('torch', columns=['input_ids', 'attention_mask', 'label'])

# Training Arguments base on BERT
training_args = TrainingArguments(
    output_dir='./results',
    eval_strategy="epoch",
    learning_rate=0.00001,  # 1e-5 learning rate
    per_device_train_batch_size=64,  # batch size
    per_device_eval_batch_size=64,
    num_train_epochs=3,  # 3 epochs
    weight_decay=0.01,
    logging_dir='./logs',
)

# Define Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
)

# Train the model
trainer.train()

# Save the model
trainer.save_model('./trained_bert')

# Evaluate the model on the test dataset
results = trainer.evaluate(eval_dataset=test_dataset)

# Profanity evaluation - Load the CSV file with profane words
profane_words_df = pd.read_excel('/content/drive/MyDrive/BERT/ProfanityListBERT.xlsx', header=None)
profane_words_df.columns = ['profanity_list']
profane_words = set(profane_words_df['profanity_list'].tolist())

# Function to check if a sentence contains profane words
def contains_profane_words(sentence, profane_words):
    words = sentence.split()
    return any(word in profane_words for word in words)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/65984 [00:00<?, ? examples/s]
# Map:   0%|          | 0/8248 [00:00<?, ? examples/s]
# Map:   0%|          | 0/8249 [00:00<?, ? examples/s]
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/content/wandb/run-20241206_153731-u5eztoz5</code>
# Syncing run <strong><a href='https://wandb.ai/annalynpelaez26-polytechnic-university-of-the-philippines/huggingface/runs/u5eztoz5' target="_blank">./results</a></strong> to <a href='https://wandb.ai/annalynpelaez26-polytechnic-university-of-the-philippines/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/annalynpelaez26-polytechnic-university-of-the-philippines/huggingface' target="_blank">https://wandb.ai/annalynpelaez26-polytechnic-university-of-the-philippines/huggingface</a>
#  View run at <a href='https://wandb.ai/annalynpelaez26-polytechnic-university-of-the-philippines/huggingface/runs/u5eztoz5' target="_blank">https://wandb.ai/annalynpelaez26-polytechnic-university-of-the-philippines/huggingface/runs/u5eztoz5</a>
#     <div>
#
#       <progress value='3093' max='3093' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3093/3093 1:03:37, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.062900</td>
#       <td>0.049692</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.034800</td>
#       <td>0.031200</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.026600</td>
#       <td>0.031175</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='129' max='129' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [129/129 00:51]
#     </div>

# %%
import torch
import pandas as pd

# Initialize counters for metrics calculation
tp = 0  # True Positives
tn = 0  # True Negatives
fp = 0  # False Positives
fn = 0  # False Negatives

# Determine the device for the model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Load CSV file
file_path = '/content/drive/MyDrive/BERT/Testing_Data - Tagalog.csv'  # Replace with your CSV file path
data = pd.read_csv(file_path)

# Loop through the rows of the DataFrame
for index, row in data.iterrows():
    sentence = row['sentence']
    true_label = row['profane']

    # Tokenize the input sentence and move to the appropriate device
    inputs = tokenizer(sentence, return_tensors="pt")
    inputs = {key: val.to(device) for key, val in inputs.items()}  # Move inputs to the same device as the model

    # Perform inference
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits

    # Get the predicted class (0: Not Profane, 1: Profane)
    predicted_class = torch.argmax(logits, dim=-1).item()

    # Update counters
    if predicted_class == 1 and true_label == 1:
        tp += 1  # True Positive
    elif predicted_class == 0 and true_label == 0:
        tn += 1  # True Negative
    elif predicted_class == 1 and true_label == 0:
        fp += 1  # False Positive
    elif predicted_class == 0 and true_label == 1:
        fn += 1  # False Negative

    # Print the result
    if predicted_class == 1:
        print(f"Sentence: '{sentence}' | Predicted: Profane | True Label: {true_label}")
    else:
        print(f"Sentence: '{sentence}' | Predicted: Not Profane | True Label: {true_label}")

# Calculate Precision, Recall, F1-Score, and Accuracy
precision = tp / (tp + fp) if (tp + fp) > 0 else 0
recall = tp / (tp + fn) if (tp + fn) > 0 else 0
f1_score = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn) if (tp + tn + fp + fn) > 0 else 0

# Display evaluation metrics
print("\nEvaluation Metrics:")
print(f"True Positives (TP): {tp}")
print(f"True Negatives (TN): {tn}")
print(f"False Positives (FP): {fp}")
print(f"False Negatives (FN): {fn}")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1_score:.4f}")
# Out:
# Sentence: 'Ilarawan kung ano ang makikita mo kung pupunta ka sa Grand Canyon.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Saang bansa ipinanganak si Pangulong Roosevelt?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Dahil sa pangalan ng kanta, hulaan ang genre ng kanta.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Maghanap ng limang pang-uri na naglalarawan sa isang mahangin na araw' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan kung paano ang papel ng kasaysayan sa mundo ngayon.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan ang kahalagahan ng data curation sa larangan ng data science.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Dahil sa sumusunod na pangungusap, i-edit ito para sa kalinawan at pagiging maikli.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Isulat muli ang pangungusap na ito upang magdagdag ng iba't ibang uri sa mga pandiwang ginamit.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ipaliwanag kung paano mag-log in sa isang computer.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sumulat ng isang maikling kuwento tungkol sa isang oso sa kakahuyan.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang halimbawa ng panunuya tungkol sa kasalukuyang sitwasyong pampulitika' | Predicted: Not Profane | True Label: 0
# Sentence: 'Maghanap ng pagkakamali sa pagbaybay sa sumusunod na pangungusap.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Para sa isang website, ano ang ibig sabihin ng SEO?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gumawa ng isang simile ng isang paglalakbay.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan ang karanasan ng pagpunta sa isang restaurant.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Suriin ang sumusunod na code at tukuyin ang isang bug.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ipaliwanag kung ano ang ibig sabihin ng "Garbage in, garbage out".' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ano ang mangyayari kung ang Earth ay tumigil sa pag-ikot?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang pangungusap na nagsasama ng mga salitang 'avocado', 'giant' at 'slice'.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gumawa ng listahan ng limang pagkain na karaniwang inihahain sa almusal.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng post sa blog ng hindi bababa sa 500 salita tungkol sa machine learning.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bibigyan ka ng isang maikling kuwento, at kailangan mong bumuo ng iba at mas mahabang bersyon ng kuwento.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sumulat ng isang patalastas na nagtataguyod ng isang produkto.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Paghambingin ang dalawang pamamaraan para sa ibinigay na gawain.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Tukuyin ang tatlong katangian ng ibinigay na species.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang diskarte para sa paglutas ng isang naibigay na problema.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bilangin kung ilang beses lumabas ang salitang 'mabilis' sa text.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng mathematical expression na nagpaparami ng 3 at 6, pagkatapos ay nagdaragdag ng 4 sa resulta.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Isulat muli ang sumusunod na pangungusap upang ito ay gumamit ng isang aktibong boses sa halip na isang tinig.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ipaliwanag ang konsepto ng "Pythagorean Theorem".' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sumulat ng maikling artikulo sa isang machine learning algorithm.' | Predicted: Not Profane | True Label: 0
# Sentence: 'I-convert ang mga decimal sa mga fraction.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Suriin ang sumusunod na pahayag: "Ang pag-aaral magdamag ay mas epektibo kaysa sa maikling pahinga."' | Predicted: Not Profane | True Label: 0
# Sentence: 'I-edit ang ibinigay na pangungusap para sa tamang paggamit ng gramatika.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Piliin ang kasalungat ng sumusunod na salita.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Mag-brainstorm ng 3 makabagong paraan ng paggamit ng machine learning.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng bagong salawikain.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Isipin kung paano magiging iba ang mundo kung ang mga computer ay hindi kailanman naimbento.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magkwento tungkol sa isang taong namumuhay sa isang eco-friendly na pamumuhay.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sa ibinigay na senaryo, hulaan ang posibilidad ng taong dumaranas ng Diabetes.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng elevator pitch para sa isang negosyong nag-aalok ng mga serbisyo sa interior design.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magdagdag ng biro sa dulo ng pangungusap.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Isulat muli ang code upang ito ay mas mahusay.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ikaw ang pinuno ng isang koponan at hiniling na magbigay ng feedback sa isang proyekto. Tukuyin ang tatlong pangunahing kalakasan at kahinaan ng proyekto.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang algorithm upang mabilang ang bilang ng mga salita sa isang ibinigay na pangungusap.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ipaliwanag ang paggamit ng martilyo' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ano ang posibleng dahilan ng isyu?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gumawa ng isang madaling recipe para sa isang malusog na almusal.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gumawa ng tweet tungkol sa Machine Learning' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang Pangunahing HTML na pahina' | Predicted: Not Profane | True Label: 0
# Sentence: 'Kunin ang ibinigay na mga input at bumuo ng isang malikhaing kuwento.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan ang pagkapangulo ni George Washington' | Predicted: Not Profane | True Label: 0
# Sentence: 'Uriin ang bansa sa kontinente.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang recipe gamit lamang ang mga sangkap na ito: sibuyas, manok, red wine, perehil' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magmungkahi ng isang malikhaing paraan upang ipakilala ang iyong sarili sa isang bagong koponan.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Tukuyin ang pinakamainam na pagkakasunud-sunod ng mga sumusunod na gawain.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Pagbukud-bukurin ang listahan ng mga instrumentong pangmusika sa tatlong magkakaibang kategorya.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sumulat ng isang hanay ng mga tagubilin upang lumikha ng isang greeting card gamit ang Adobe Photoshop' | Predicted: Not Profane | True Label: 0
# Sentence: 'Kalkulahin ang kabuuan gamit ang mga sumusunod na input' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ano ang mga pakinabang ng isang puno ng desisyon?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Tukuyin ang tao, lugar, o bagay na tinutukoy sa sumusunod na pangungusap.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sumulat ng isang slogan para sa isang kumpanya na nagbebenta ng napapanatiling damit.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sumulat ng isang maikling salaysay mula sa pananaw ng isang tao na ang libangan ay mangolekta ng mga selyo.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magbigay ng isang katangian ng karakter na maaaring maiugnay sa pamumuno' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sumulat ng isang tula na naglalaman ng mga ibinigay na salita: "ilog" at "liwanag"' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gayahin ang isang pangunahing lohika ng computer gamit ang ibinigay na mga kundisyon ng boolean.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Hanapin ang bilang ng mga 2-titik na salita sa wikang Ingles.' | Predicted: Not Profane | True Label: 0
# Sentence: 'I-frame ang sumusunod na pahayag upang magbigay ng positibong pananaw.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Dahil sa isang string, baligtarin ang pagkakasunud-sunod ng mga character at i-print ito sa screen' | Predicted: Not Profane | True Label: 0
# Sentence: 'Maglagay ng angkop na pagbati sa simula ng ibinigay na email.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Dahil sa listahan ng mga salita, ilang salita ng tatlong letra ang maaaring mabuo?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ano ang karaniwang taunang suweldo para sa isang developer ng serbisyo sa customer?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magdagdag ng dalawang elemento upang gawing nakakatawa ang pangungusap na ito.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magbigay ng 5 halimbawa ng mga salita na nauugnay sa damdamin ng "malungkot".' | Predicted: Not Profane | True Label: 0
# Sentence: 'I-type ang code na nagpapakita ng sumusunod na output:' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ibuod ang iyong mga natuklasan pagkatapos magsaliksik tungkol sa AI.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan ang hamon ng pagkakaroon ng abalang pamumuhay.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng listahan ng Pros and Cons para sa isang partikular na aktibidad.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magdisenyo ng isang eksperimento upang subukan ang pagiging epektibo ng ibinigay na produkto.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng mga tanong para sa sumusunod na pahayag.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ihambing at ihambing ang mga tungkulin ng isang tagapagturo at isang politiko.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ano ang estado ng sining para sa pananaliksik sa computer vision?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ipaliwanag kung bakit maaaring gumamit ng mga taripa ang isang bansa' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magdisenyo ng survey ng customer para sa isang restaurant' | Predicted: Not Profane | True Label: 0
# Sentence: 'Paghambingin at paghambingin ang dalawang magkaibang disiplina sa loob ng AI.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sumulat ng ilang pangungusap tungkol sa ibinigay na cartoon character.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Hulaan ang trend para sa sumusunod na data.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng random na pangungusap batay sa ibinigay na konteksto: Lumakad siya sa buong field.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Maglista ng 3 magandang halimbawa ng balanseng diyeta.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Aling uri ng anggulo ang 90 degrees?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magmungkahi ng dalawang posibleng pagsasanay na makakatulong sa gumagamit na magsanay ng bokabularyo ng Ingles.' | Predicted: Not Profane | True Label: 0
# Sentence: 'I-edit ang salitang "masarap" para makabuo ng tamang salita.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ayusin muli ang pagkakasunod-sunod ng mga salita sa ibaba upang makabuo ng wastong pangungusap.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Tukuyin ang pangunahing ideya ng artikulong ito' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magdisenyo ng laro na kinabibilangan ng sumusunod na genre: -' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ipaliwanag kung bakit dapat kang pumili ng isang organic na kutson.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Paano makikinabang ang mga negosyo sa paggamit ng AI?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ibuod ang mga nilalaman ng sumusunod na artikulo sa 2 pangungusap' | Predicted: Not Profane | True Label: 0
# Sentence: 'Mangyaring hulaan ang mga sumusunod na salita batay sa mga pahiwatig na ibinigay.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Mag-isip ng malikhaing paraan ng paggamit ng augmented reality.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Suriin ang sumusunod na pangungusap: "Ang malamig na hangin ng taglamig ay kumaluskos sa mga dahon".' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ano ang ibig sabihin ng 'a priori'?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Maghanap ng isang paraan upang gawing mas kawili-wili ang pangungusap na ito' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng listahan ng 5 item na pinakamalamang na mahahanap namin sa isang garahe.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Dahil sa talahanayan ng data, tukuyin kung sumusunod ito sa normal na distribusyon.' | Predicted: Not Profane | True Label: 0
# Sentence: 'I-edit ang ibinigay na text para maging mas pormal ito.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ipaliwanag ang mga pagkakaiba sa pagitan ng relative at absolute path sa isang computer.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Tukuyin ang uri ng pangungusap ng: Luma na ang aking kompyuter.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gumawa ng listahan ng mga benepisyo sa kalusugan ng pagiging aktibo.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ikategorya ang mga sumusunod na bagay sa 'prutas' o 'gulay': saging, patatas, kamatis' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ihambing at ihambing ang dalawang karakter mula sa "The Cat in the Hat" ni Dr. Seuss.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ipaliwanag ang kahulugan ng idiomatic expression na "It takes two to tango"' | Predicted: Not Profane | True Label: 0
# Sentence: 'Isulat muli ang sumusunod na parirala gamit ang idyoma na "over the moon".' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magmungkahi ng paraan upang mabawasan ang pagkonsumo ng papel.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang listahan ng 5 hakbang upang matiyak ang tagumpay ng proyekto.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang eksperimento upang sukatin ang kasiyahan ng customer sa isang chatbot ng customer' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng 10-digit na random na numero.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang pun mula sa mga salitang 'giraffe' at 'elephant'' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ipaliwanag ang dinamika ng isang mapanganib na relasyon.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ayusin ang tatlong piraso ng impormasyong ito ayon sa pagkakasunod-sunod' | Predicted: Not Profane | True Label: 0
# Sentence: 'Maglista ng limang paraan ng pagsusuri ng datos.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Mangolekta ng data mula sa sumusunod na mapagkukunan at ibuod ang mga ito sa isang talahanayan.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Isulat muli ang pangungusap upang maging mas malinaw ang kahulugan nito nang hindi binabago ang pangunahing punto nito.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Maglista ng 5 mga milestone sa pag-unlad ng sikolohikal para sa mga batang nasa edad 1-2 taon.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang kumpletong pangungusap gamit ang mga ibinigay na salita.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Kunin ang pangungusap na ito at gawing mas pormal na istilo: Oras na para bumalik sa trabaho ngayon.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gumawa ng haiku (3 linya na may syllabic pattern na 5/7/5) na gumagamit ng pariralang "summer night".' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan ang isang halimbawa kung kailan maaaring maging kapaki-pakinabang ang ibinigay na pamamaraan.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng hypothetical na sitwasyon kung saan nalulungkot ang isang tao' | Predicted: Not Profane | True Label: 0
# Sentence: 'Dahil sa ilang tanong at sagot mula sa isang online na kurso, uriin ang uri ng mga tanong.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang wastong query sa database mula sa mga sumusunod na parameter.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bigyan mo ako ng diskarte upang makayanan ang stress sa lugar ng trabaho.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang plano sa laro upang mabawasan ang basura.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Mag-brainstorm ng tatlong feature na maaaring magpahusay sa isang smartphone' | Predicted: Not Profane | True Label: 0
# Sentence: 'Maghanap ng isang halimbawa ng isang uri ng algorithm ng pag-encrypt.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng data visualization tungkol sa bilang ng mga taong dumalo sa isang konsiyerto' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ano ang iba't ibang elemento ng electrical circuit?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ibuod ang mga etikal na implikasyon ng paggamit ng AI sa larangang medikal.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan kung paano maaaring magdulot ng kagalakan ang isang matriarch ng pamilya sa kanilang pamilya.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan kung paano huhubog ng artificial intelligence (AI) ang hinaharap ng medisina.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magbigay ng tatlong punto ng paghahambing sa pagitan ng refrigerator at microwave.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magbigay ng tatlong bagay na ginagawang hindi malilimutan ang isang salu-salo sa hapunan.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Aling mga trabaho ang nauugnay sa pagsusuri sa pananalapi?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan ang paraan para sa paglutas ng isang partikular na problema.' | Predicted: Not Profane | True Label: 0
# Sentence: 'I-rotate ang matrix na ito 90 degrees clockwise' | Predicted: Not Profane | True Label: 0
# Sentence: 'Anong uri ng kagamitang pampanitikan ang ginagamit sa pangungusap na ito?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan ang mga pinakakaraniwang sanhi ng pananakit ng ulo.' | Predicted: Not Profane | True Label: 0
# Sentence: 'I-edit ang ibinigay na pangungusap upang gawin itong angkop para sa isang pormal na konteksto.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Suriin ang sumusunod na pahayag: Pinadali ng mga app ang ating buhay' | Predicted: Not Profane | True Label: 0
# Sentence: 'Pagsamahin ang dalawang pangungusap sa isang pangungusap nang hindi nawawala ang kahulugan.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Suriin ang sumusunod na artikulo ng balita at magbigay ng maikling buod.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Hanapin ang "The Verge" at magbigay ng buod' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magmungkahi ng solusyon upang mabawasan ang pagkapagod sa online na paaralan.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ihambing ang dalawang karakter sa isang nakakaintriga na paraan' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan sa dalawang pangungusap ang pagkakaiba sa pagitan ng isang programming language at isang markup language' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang pangungusap na gumagamit ng mga ibinigay na salita sa ibinigay na pagkakasunud-sunod.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan ang papel ng data science sa industriya ng pangangalagang pangkalusugan' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magbigay ng tatlong pangungusap upang ipaliwanag ang kahulugan ng "artificial intelligence".' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gumawa ng plano sa badyet ng pamilya.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Mag-brainstorm ng tatlong malikhain at natatanging paraan upang palamutihan ang isang silid.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ikategorya ang sumusunod na pangungusap bilang halimbawa ng pangungusap na pautos o pangungusap na patanong.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Suriin ang programang ito para sa mga kalakasan at kahinaan nito.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng algorithm para sa pagbibilang hanggang lima.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magbigay ng 5 pangyayari na naganap noong Ikalawang Digmaang Pandaigdig.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Dahil sa dalawang salita, "bahay" at "tagsibol", lumikha ng limang salita na parirala.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ibigay ang mga kalamangan at kahinaan ng ibinigay na sitwasyon.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magbigay ng dalawang hayop na hindi mammal.' | Predicted: Profane | True Label: 0
# Sentence: 'Sagutin ang isang maikling sagot na tanong' | Predicted: Not Profane | True Label: 0
# Sentence: 'I-parse ang sumusunod na HTML code at lumikha ng DOM tree' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gumawa ng jingle para sa isang produktong pangkalusugan na pagkain.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng limang tip para sa pagtuturo ng Ingles.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ano ang layunin ng resume?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magdisenyo ng user interface ng telepono para sa isang app sa pagpaplano ng paglalakbay' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan ang isang web page sa sumusunod na format: Header, Body, Footer.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan ang isang paraan upang pamahalaan ang stress sa panahon ng trabaho.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Tukuyin ang propesyon na may kaugnayan sa pangungusap.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sumulat ng isang function na nakakahanap ng ika-n term sa isang Fibonacci sequence.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Pangalanan ang limang estado ng US na nagsisimula sa letrang "A"' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan ang mga pangunahing bahagi ng sistema ng pagtunaw ng tao.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gamit lamang ang limang salita, ilarawan ang isang eksena sa pelikula.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sa pangungusap, "Nakatanggap si Jack ng regalo sa kaarawan mula sa kanyang tiyahin na si Mary," tukuyin ang paksa.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Tukuyin kung anong uri ng tatsulok ang may mga gilid na may haba na 3, 4, at 5.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Uriin ang ibinigay na hayop sa alinman sa reptilya o mammal.' | Predicted: Profane | True Label: 0
# Sentence: 'Kunin ang mga ibinigay na pangungusap at gumawa ng bagong pangungusap gamit ang mga ito gamit ang isang tutuldok para sa diin.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sumipi ng tatlong pinagmumulan ng mga epekto ng basurang plastik sa kapaligiran.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng bagong expression para ilarawan ang isang taong laging huli.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magmungkahi ng isang menu ng hapunan malusog na hapunan para sa linggo.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Kalkulahin ang sumusunod na expression.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Pangalan ng maraming uri ng artificial intelligence hangga't maaari.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Maghanap online at magbigay ng tumpak na kahulugan sa isang ibinigay na konsepto.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gumawa ng listahan ng mga pang-uri upang ilarawan ang ibinigay na pangngalan.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Hanapin mo ako ng ilang nakakatawang quotes mula sa isang sikat na komedyante.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Pangalanan ang tatlong panganib na nauugnay sa online banking.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Pangalanan ang unang limang conveners ng United Nations' | Predicted: Not Profane | True Label: 0
# Sentence: 'Tukuyin ang uri ng reaksyong kemikal para sa sumusunod na equation.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan ang karakter ni Arthur sa kwentong ito.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Suriin ang epekto ng teknolohiya sa lugar ng trabaho.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Dahil sa input, bumuo ng isang listahan ng limang adjectives.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Iugnay ang dalawang ideya mula sa sipi.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Hanapin ang pinakamaikling ruta upang maabot ang isang destinasyon.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Para sa isport na ito, ano ang pangalan ng kagamitang ginagamit sa paghuli ng bola?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Maglista ng dalawang dahilan ng global warming.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Hanapin ang kahulugan ng salitang "epiphany".' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang malikhaing recipe para sa chocolate cookie.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gumawa ng tweet na may haba na 140 character o mas kaunti bilang tugon sa sumusunod:' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ihambing ang mga karakter sa Alice's Adventures in Wonderland at Through the Looking-Glass.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magpasya kung ito ay isang pahayag, tanong, pautos, o tandang.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang halimbawa ng patakarang laban sa diskriminasyon.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Dahil sa isang dataset ng mga presyo ng stock para sa 3 kumpanya, uriin kung aling mga stock ang may mas mataas na presyo.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang tula na may ibinigay na tema' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ibuod ang nobelang "The Lord of the Rings".' | Predicted: Not Profane | True Label: 0
# Sentence: 'Mag-brainstorm ng tatlong solusyon para mapabuti ang pampublikong transportasyon.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gumawa ng outline para sa isang artikulong tumatalakay sa paggamit ng AI sa pangangalagang pangkalusugan.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magbigay ng dalawang dahilan kung bakit maaaring humingi ng therapy ang isang tao.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ano ang tinatayang circumference ng Earth?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gumawa ng talata batay sa mga katotohanang ito.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sumulat ng isang dula tungkol kay Romeo at Juliet.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Pagsusuri ng damdamin ng teksto sa ibaba.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gumawa ng tula tungkol sa AI gamit ang AABB rhyme scheme.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng tulang haiku gamit ang mga sumusunod na salita: buwan, ilog, at puso.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Paano natin madaragdagan ang pokus?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magpakilala ng isang tunay na halimbawa sa mundo na naaangkop sa sumusunod na pahayag.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ibuod ang sumusunod na talata: Ang mundo ng teknolohiya ay mabilis na nagbabago. Noong nakaraan, ang mga computer at iba pang teknolohiya ay hindi gaanong advanced kaysa sa ngayon.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Pangalanan ang 5 sikat na web framework.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ano ang mga karaniwang uri ng tula?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Palitan ang salitang 'kuripot' ng mas angkop na salita sa pangungusap.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan ang pinakamalaking paliparan sa US' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ihambing ang klima ng dalawang rehiyon sa US (hal. Midwest at Northeast).' | Predicted: Not Profane | True Label: 0
# Sentence: 'Uriin ang sumusunod na pangungusap sa Pangngalan, Pandiwa at Pang-uri.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Tukuyin kung anong uri ng hayop ang inilalarawan ng sumusunod na pangungusap.' | Predicted: Profane | True Label: 0
# Sentence: 'Uriin ang sumusunod na artikulo bilang tumpak o hindi tumpak.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan ang proseso kung paano nagiging psychologist ang isang tao.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ano ang kahulugan ng "convergence" sa matematika?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Paraphrase ang pangungusap para maalis ang cliche.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ipaliwanag kung ano ang ginagawa ng function na 'count_words' sa Python.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sumulat ng isang 500-salitang kuwento tungkol sa isang batang ulila na nakatuklas ng isang nakatagong mahiwagang kapangyarihan.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magmungkahi ng sukatan para sa pagpapasya kung aling modelo ang gumaganap nang mas mahusay para sa isang partikular na problema.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gumawa ng listahan ng mga tanong sa pananaliksik para sa isang partikular na paksa.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng modernong bersyon ng pariralang "a watched pot never boils".' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magdagdag ng 'ed' sa pandiwa upang mabuo ang past tense' | Predicted: Not Profane | True Label: 0
# Sentence: 'Pangalanan ang isang teknikal na tool na maaaring gamitin upang pag-aralan ang sumusunod na data' | Predicted: Not Profane | True Label: 0
# Sentence: 'Lumikha ng modelo ng pag-uuri upang matukoy kung ang isang ibinigay na mammal ay isang carnivore o isang herbivore.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan ang visualization ng isang kawan ng mga ibon na lumilipat.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan kung paano magse-set up ang isang user ng account sa isang bagong social media site.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Maglista ng tatlong katangian ng pusa' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sumulat ng query upang piliin ang lahat ng mga email ng user mula sa talahanayan ng database ng "Mga User."' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sumulat ng headline para sa isang artikulo ng balita na tumatalakay sa mga pagsulong sa artificial intelligence.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang pangungusap gamit ang mga sumusunod na input words: ardilya, atsara, maliit na bahay.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magdisenyo ng isang quiz website.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sa pangungusap sa ibaba, tukuyin ang paksa, pandiwa, at layon.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gumawa ng poster para sa pelikulang "Spider-Man: Far from Home".' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan ang pag-uugali ng isang unggoy para sa sumusunod na sitwasyon.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ipaliwanag kung bakit mahalagang mag-ipon para sa kinabukasan.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Kalkulahin ang perimeter ng isang tatsulok na ang mga gilid ay 6, 7 at 8' | Predicted: Not Profane | True Label: 0
# Sentence: 'Baguhin ang sumusunod na parirala upang makagawa ng isang retorika na tanong' | Predicted: Not Profane | True Label: 0
# Sentence: 'Talakayin ang kahalagahan ng wastong pamamahala ng espasyo sa isang opisina.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magdagdag ng 3 detalye sa teksto upang gawin itong mas kawili-wili.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Dahil sa isang set ng data, i-edit ang mga entry para baguhin ang text para ma-capitalize ang unang titik ng lahat ng salita.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gumawa ng timeline na naglalarawan sa mga pangunahing kaganapan na humahantong sa World War II.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sumulat ng pambungad na pahayag para sa isang presentasyon' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ipaliwanag ang sumusunod na sipi.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ipaliwanag kung paano mananatiling motivated ang isang tao kapag nagtatrabaho mula sa bahay.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magmungkahi ng hypothesis batay sa datos ng survey.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng maikling pag-uusap sa pagitan ng dalawang tao na nagpapahayag ng paghanga sa ikatlong tao.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Dahil sa listahan ng mga sangkap, magmungkahi ng isang recipe na kinabibilangan ng mga sangkap.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng slogan para sa isang startup na kumpanya na tumutuon sa pagbibigay ng mga serbisyong eco-friendly.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magbigay ng isang uri ng pagsasanay na maaaring ibigay ng mga kumpanya para sa kanilang mga empleyado?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Dahil sa isang artikulo, tukuyin ang pananaw ng pangunahing may-akda.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ibuod ang mga pangunahing punto mula sa isang ibinigay na dokumento.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magbigay ng halimbawa kung paano maging mas mabuting tagapakinig.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ihambing ang ibinigay na dalawang bansa sa mga tuntunin ng populasyon.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gumawa ng slogan ng marketing campaign para sa isang negosyo sa pag-aayos ng alagang hayop.' | Predicted: Profane | True Label: 0
# Sentence: 'Ipagpalagay na binigyan ka ng dalawang numero, 14 at 79. Bumuo ng isang pangungusap na naglalarawan ng pagkakaiba sa laki ng dalawang numerong ito.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Tukuyin ang 3 pagkakaiba sa pagitan ng data science at artificial intelligence.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Isipin na nagbibigay ka ng isang pagtatanghal sa isang malaking grupo ng mga tao, lumikha ng isang kaakit-akit na panimula para sa iyong presentasyon.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Tukuyin ang pariralang pangngalan ng pangungusap sa ibaba' | Predicted: Not Profane | True Label: 0
# Sentence: 'Piliin ang tamang spelling ng salitang "kailangan".' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sabihin sa akin kung ano ang gagawin mo kung nanalo ka ng isang milyong dolyar' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bigyan mo ako ng metapora para ilarawan ang isang matinding tunggalian.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Isulat muli ang sumusunod na pangungusap upang palitan ang anumang mga pariralang clichÃ©.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Alamin ang pinakasikat na isport sa Canada.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sumulat ng maikling talambuhay ni Alexander the Great.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng listahan ng tatlo hanggang limang tanong na maaaring itanong ng isang tao sa isang interbyu.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Hanapin ang nakatagong mensahe sa string ng mga salita' | Predicted: Not Profane | True Label: 0
# Sentence: 'Awtomatikong ayusin ang anumang mga error sa bantas o spelling sa pangungusap na ito.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sumulat ng isang talata na naglalarawan sa mga pangunahing prinsipyo ng psychoanalysis.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan ang modelo ng wika ng GPT-3.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ibinigay ang dalawang numero at isang operator (+, - , * , /) suriin ang expression.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Basahin ang isang ibinigay na artikulo at magmungkahi ng isang maaaksyunan na susunod na hakbang para sa problemang tinalakay.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Isulat muli ang pangungusap na ito gamit lamang ang 6 na salita.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Kilalanin at uriin ang ibinigay na pigura.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan sa 50 salita o mas kaunti ang lutuin ng iyong lungsod.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Dahil sa isang senaryo, magdisenyo ng antas ng laro.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang katanungan na maaaring itanong ng isang tao sa isang pakikipanayam sa trabaho.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang tamang programa ng python upang ilipat ang lahat ng mga titik sa isang ibinigay na salita sa pamamagitan ng dalawang character sa unahan.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Basahin ang sumusunod na pangungusap at magmungkahi ng alternatibong bersyon na mas mapaglarawan.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Anong paraan ng API ang iyong gagamitin para makuha ang bilang ng mga mensaheng ipinadala ng isang user sa nakalipas na 30 araw?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Hanapin ang mga salitang tumutula para sa ibinigay na salita.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ibuod ang daloy at ideya ng sumusunod na talata.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Lumikha ng isang pagpipinta ng isang patlang sa tag-araw' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng thesis statement para sa isang research paper sa kasaysayan ng US healthcare system.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gumawa ng listahan ng mga tanong sa pakikipanayam upang suriin ang isang potensyal na pag-upa para sa posisyon ng kinatawan ng serbisyo sa customer.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan ang istruktura ng isang pamahalaan sa isang autokrasya.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Uriin ang bawat isa sa mga sumusunod na pahayag bilang totoo, mali, o hindi alam, batay sa karaniwang kaalaman at intuwisyon.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sabihin sa akin ang tatlong dahilan ng stress' | Predicted: Not Profane | True Label: 0
# Sentence: 'Kasunod ng input, maglista ng dalawang paraan na magagamit ng mga kumpanya ang teknolohiya sa pagkilala sa mukha para mapahusay ang karanasan ng customer.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Paano mo ilalarawan ang pagkakaiba sa pagitan ng presyo at halaga?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sa dalawang pangungusap, ipaliwanag ang tatlong batas ng thermodynamics.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Uriin ang sumusunod na pangungusap bilang sang-ayon o negatibo: "Hindi pa siya pumupunta sa tindahan"' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magbigay ng detalyadong paliwanag ng formula ng Euler.' | Predicted: Not Profane | True Label: 0
# Sentence: 'I-edit ang sumusunod na mensahe upang ito ay angkop para sa isang pormal na kapaligiran sa trabaho.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magbigay ng argumento kung bakit ang ilang tao sa online ay mas malamang na maging anonymous kaysa sa iba.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gumawa ng orihinal na kwento tungkol sa isang elepante' | Predicted: Not Profane | True Label: 0
# Sentence: 'Piliin ang bansang WALA sa EU' | Predicted: Not Profane | True Label: 0
# Sentence: 'Pangalanan ang isang pangunahing elemento para sa pagdidisenyo ng isang epektibong chatbot.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan ang isang karakter na nabubuhay sa isang post-apocalyptic na mundo.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ibuod ang sipi sa anim na salita.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan kung paano mo gagamitin ang isang badyet upang lumikha ng katatagan sa pananalapi.' | Predicted: Not Profane | True Label: 0
# Sentence: 'I-convert ang sumusunod na numero sa dalawang digit na base 8 (octal) na numero.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sumulat ng algorithm na bumubuo ng array ng even na mga numero mula 0 hanggang 100' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ibuod ang mga pangunahing argumento sa isang ibinigay na artikulo' | Predicted: Not Profane | True Label: 0
# Sentence: 'Maglista ng 3 tampok ng isang epektibong disenyo ng website.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Baguhin ang teksto upang ito ay sumunod sa nakakatawang tono. Bumili ng bagong kotse sina John at Amy.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ibuod ang isang pag-uusap sa pagitan ng dalawang tao na tinatalakay ang kanilang huling bakasyon.' | Predicted: Not Profane | True Label: 0
# Sentence: 'I-edit ang salitang ito na pangungusap.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Dahil sa sumusunod na pangungusap, sumulat ng tanong sa matematika na nauugnay dito.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ipaliwanag ang kahalagahan ng paggamit ng data visualization.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang pag-aaral sa pananaliksik upang ihambing ang mga epekto ng pagmumuni-muni at ehersisyo sa mga antas ng pagkabalisa.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Anong uri ng sugnay ang naka-highlight na bahagi ng pangungusap?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ipaliwanag ang sumusunod na axiom' | Predicted: Not Profane | True Label: 0
# Sentence: 'I-edit ang tekstong ito upang ito ay maging mas kapani-paniwala at propesyonal.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng dalawang libong salita ng diyalogo sa pagitan ng dalawang karakter.' | Predicted: Not Profane | True Label: 0
# Sentence: 'I-rank ang mga sumusunod na bansa ayon sa GDP per capita' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan ang listahan ng mga sangkap para sa isang recipe ng guacamole.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Pagbukud-bukurin ang mga numero 3, 7, at 9 sa pababang pagkakasunod-sunod' | Predicted: Not Profane | True Label: 0
# Sentence: 'Mag-imbento ng bagong salita sa pamamagitan ng pagsasama ng dalawang umiiral na salita.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gumawa ng buod ng sumusunod na artikulo: https://www.nytimes.com/2021/04/20/books/the-night-sun.html' | Predicted: Not Profane | True Label: 0
# Sentence: 'Binigyan ka ng isang artikulo at kailangan mong uriin ito ayon sa mga paksa nito. I-output ang mga paksa nang paisa-isa, na pinaghihiwalay ng kuwit.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Anong mga variable ng kapaligiran ang kinakailangan upang magpatakbo ng isang Java program?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Tukuyin ang 'artificial neural network'.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang kuwento na nagsisimula sa sumusunod na pangungusap: Hindi pa siya nakakita ng katulad nito dati.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ipaliwanag kung paano magdisenyo ng arkitektura ng software.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Hanapin ang tono sa tulang ito.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Sumulat ng isang sanaysay tungkol sa panlipunang implikasyon ng artificial intelligence' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ano ang dalawang potensyal na panganib na nauugnay sa paggamit ng cloud storage?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Anong konklusyon ang maaaring makuha mula sa ibinigay na datos?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Tukuyin ang isang kawili-wiling katotohanan tungkol sa Saturn.' | Predicted: Not Profane | True Label: 0
# Sentence: 'I-edit ang sumusunod na pangungusap para maging mas pormal ito: "nag-usap kami sa telepono"' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang tweet na isang tugon sa isang tweet tungkol sa mga benepisyo ng ehersisyo.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan ang pagpipinta na "The Starry Night" ni Vincent Van Gogh sa isang pangungusap.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Tukuyin kung aling bersyon ng sumusunod na aklat ang mas bago.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan ang pangunahing ideya ng maikling kuwentong ito' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magbigay ng dalawang hayop na makikita sa African savanna.' | Predicted: Profane | True Label: 0
# Sentence: 'Magmungkahi ng angkop na laro ng card para sa isang birthday party na may 10 taong gulang na mga bata.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Gumawa ng slogan para sa SpaceX' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ano ang ilang karaniwang diskarte sa pagiging magulang upang maitanim ang disiplina sa isang bata?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang makatwirang listahan ng limang mga item na maaaring nakaimpake para sa isang maghapong paglalakad' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ilarawan kung ano ang emosyonal na katalinuhan.' | Predicted: Not Profane | True Label: 0
# Sentence: 'I-update ang sumusunod na talahanayan gamit ang isang bagong column' | Predicted: Not Profane | True Label: 0
# Sentence: 'Baligtarin ang mga tuntunin ng serye 2,4,6,8,....' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magbigay ng tatlong halimbawa ng mga halaman na namumulaklak sa lilim.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Uriin ang sumusunod na pangungusap bilang isang pahayag o tanong: "Ang pusa ay tumalon sa mesa".' | Predicted: Not Profane | True Label: 0
# Sentence: 'Kalkulahin ang lugar ng isang regular na polygon na may haba ng gilid na 4cm at 8 gilid.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magmungkahi ng isang paraan upang mawala ang 10 pounds sa loob ng dalawang linggo.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Tukuyin ang uri ng pangungusap sa pariralang ito' | Predicted: Not Profane | True Label: 0
# Sentence: 'Kumbinsihin ako kung bakit ko dapat bilhin ang Apple iPhone 12.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Lumikha ng isang pun batay sa salitang "payong".' | Predicted: Not Profane | True Label: 0
# Sentence: 'Baguhin ang nilalaman ng pangungusap upang magamit ang past tense.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Hanapin ang nawawalang numero sa sequence: 3, 5, 7, __, 13' | Predicted: Not Profane | True Label: 0
# Sentence: 'I-convert ang pangungusap sa negatibong anyo nito nang hindi binabago ang kahulugan.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Magbigay ng halimbawa ng isang sitwasyon kung kailan dapat kong gamitin ang pagpapasya.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ihambing at ihambing ang mga sistema ng edukasyong Amerikano at Tsino.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ikategorya ang mga sumusunod na pamagat ng pelikula bilang horror, comedy, o drama.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Paano gumagana ang dashboard ng aking sasakyan?' | Predicted: Not Profane | True Label: 0
# Sentence: 'Ipaliwanag ang kahulugan ng pariralang "pagkagat sa kamay na nagpapakain sa iyo".' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng isang nakakatawang one-liner tungkol sa mga robot.' | Predicted: Not Profane | True Label: 0
# Sentence: 'Bumuo ng pseudocode para sa pag-uuri ng array.' | Predicted: Not Profane | True Label: 0
# ...
# Sentence: 'mali ata naquote mo tanga' | Predicted: Profane | True Label: 1
# Sentence: 'parang silang tanga wala namang attractive kay skusta kadiri' | Predicted: Profane | True Label: 1
# Sentence: 'kanina pa in progress daw pakyu tong shopee pay gago' | Predicted: Profane | True Label: 1
# Sentence: 'bwiset ka steve kerr' | Predicted: Profane | True Label: 1
# Sentence: 'napaka bobo mo naman haha story story pa kasi ng lalaki eh tangina ng badong na yan' | Predicted: Profane | True Label: 1
# Sentence: 'wag kang mag malinis tarantado feeling malinis ka ulol bantot' | Predicted: Profane | True Label: 1
# Sentence: 'basta alam ko ikaw yung kupal na kaibigan sa ating dalawa' | Predicted: Profane | True Label: 1
# Sentence: 'kupal naman ni imee' | Predicted: Profane | True Label: 1
# Sentence: 'ang boring tangina tapos di pako makatulog bwiset' | Predicted: Profane | True Label: 1
# Sentence: 'grr pakyu po gusto niyo po away' | Predicted: Profane | True Label: 1
# Sentence: 'ayoko na mga tarantado' | Predicted: Profane | True Label: 1
# Sentence: 'tangina malapit na yung kaba ko shit lang' | Predicted: Profane | True Label: 1
# Sentence: 'pakyu lagi nalang walang kuryente' | Predicted: Profane | True Label: 1
# Sentence: 'tangina naman oh hindi na ako kasama dimagiba sa birthday salubong ni bella wala na sad na ako araw at gabi' | Predicted: Profane | True Label: 1
# Sentence: 'tangina niyo hindi ko kinakaya pakshet' | Predicted: Profane | True Label: 1
# Sentence: 'pucha haha yenyen retirement plan ng lola era' | Predicted: Profane | True Label: 1
# Sentence: 'tangina ng xenon na yan sige lang reply ko sa chat niya tapos oy wag ka magtampo wala akong pera ngayon ano ako mukang pera gago ka ba' | Predicted: Profane | True Label: 1
# Sentence: 'putangina pakaba si donny sa instagram post niya' | Predicted: Profane | True Label: 1
# Sentence: 'sayawan ko nalang kayo putangina' | Predicted: Profane | True Label: 1
# Sentence: 'gago ready ka na ba haha' | Predicted: Profane | True Label: 1
# Sentence: 'pucha pagod na pagod na kamay pati isip ko sa kagagawa ng mga essays napapagod na rin ako para sa sarili ko kasi bakit ba ako pa talaga gumagawa marami naman sa mga google na sagot talaga' | Predicted: Profane | True Label: 1
# Sentence: 'pre test palang naman pero pag nakakakuha ako ng mababa parang feeling ko ang bobo ko' | Predicted: Profane | True Label: 1
# Sentence: 'tatanga tanga na si law renz' | Predicted: Profane | True Label: 1
# Sentence: 'pucha bakit kakampink nanaman' | Predicted: Profane | True Label: 1
# Sentence: 'kahit sa airport na malayuan ko lang makita okay na sana tangina naman' | Predicted: Profane | True Label: 1
# Sentence: 'tangina mo lalo akong nalungkot sa sinend mo ulol ka' | Predicted: Profane | True Label: 1
# Sentence: 'tangina niyo ha kala niyo di ko kayo papatulan tangina mga hindot' | Predicted: Profane | True Label: 1
# Sentence: 'ngayon ko lang napanood yung ano ni mark pakshet haha mahina talaga ako sa mga malalalim yung boses' | Predicted: Profane | True Label: 1
# Sentence: 'putangina panga na ito puta' | Predicted: Profane | True Label: 1
# Sentence: 'asarin ko din kaya sila pag nag break sila hindi ba magagalit din siya tarantado ka' | Predicted: Profane | True Label: 1
# Sentence: 'tanga walang bebe bebe pag elves haha' | Predicted: Profane | True Label: 1
# Sentence: 'ngayon lang yan tanga' | Predicted: Profane | True Label: 1
# Sentence: 'haha putangina kinabahan ako dun sa pa instagram post ha' | Predicted: Profane | True Label: 1
# Sentence: 'gago ayoko na haha' | Predicted: Profane | True Label: 1
# Sentence: 'mag aangkas nanaman ako pucha' | Predicted: Profane | True Label: 1
# Sentence: 'ang babaw ng kaligayahan ko pakshet' | Predicted: Profane | True Label: 1
# Sentence: 'gago putangina ang ganda mami' | Predicted: Profane | True Label: 1
# Sentence: 'tangina bakit kase ang unstable ng mental health ko ngayon' | Predicted: Profane | True Label: 1
# Sentence: 'wala na kong amor sayong kupal ka' | Predicted: Profane | True Label: 1
# Sentence: 'puta magaling talaga yung kalaban namin' | Predicted: Profane | True Label: 1
# Sentence: 'ayoko na magbiro sa pamilya ko pucha sobrang seryoso' | Predicted: Profane | True Label: 1
# Sentence: 'pakyu hindi ako makatigil sa pag kain' | Predicted: Profane | True Label: 1
# Sentence: 'haha ulol may poging bumili sa tindahan namin kaso hindi ko kilala' | Predicted: Profane | True Label: 1
# Sentence: 'ubos na yung tissue ko gago lotion nalang natira' | Predicted: Profane | True Label: 1
# Sentence: 'pucha andaming nangyayari ano ba naman' | Predicted: Profane | True Label: 1
# Sentence: 'umuwi kana please mag data kana lang doon sainyo bwiset ka' | Predicted: Profane | True Label: 1
# Sentence: 'tuloy ngayon kasi nararamdaman ko talagang mag coconcert sila dito tapos wala ako naipon ay pakshet talaga malas ako' | Predicted: Profane | True Label: 1
# Sentence: 'sobrang blooming ni pau today i mean gago vebs maganda gwapo cute lahat lahat naman si pau as always pero iba ang bloom niya punyeta may flower kaya yung kapeng ininom niya napakaganda talaga' | Predicted: Profane | True Label: 1
# Sentence: 'bobo mo puta kita mong nagagalit din si crdj deserved ng adu yun dahil napaka ganda ng nilaro nila' | Predicted: Profane | True Label: 1
# Sentence: 'nagooverthink nanaman ako pucha naman' | Predicted: Profane | True Label: 1
# Sentence: 'pakyu ka kasi mcbeth di mo deserve si pia' | Predicted: Profane | True Label: 1
# Sentence: 'sorry bobo lang ako' | Predicted: Profane | True Label: 1
# Sentence: 'thanks beh pakyu ka talaga' | Predicted: Profane | True Label: 1
# Sentence: 'bwiset buong school year binigay lang sakin ng tle at science ay anxiety' | Predicted: Profane | True Label: 1
# Sentence: 'deserve ko ba itong ganto punyeta' | Predicted: Profane | True Label: 1
# Sentence: 'anyways matutulog na lang ulit ako pucha' | Predicted: Profane | True Label: 1
# Sentence: 'di lang ikaw gago akoy pagod na' | Predicted: Profane | True Label: 1
# Sentence: 'nag papakilala ka be ngayon alam ko na na kupal ka at plastik ka' | Predicted: Profane | True Label: 1
# Sentence: 'haha pucha pati kasama ko sinusuportahan ka pala sa kaibigan nya' | Predicted: Profane | True Label: 1
# Sentence: 'gago ka putangina mo' | Predicted: Profane | True Label: 1
# Sentence: 'saan ka pinagpala sa babaeng binayaran mo tanga huwag kang magalala hintayin mo yung karma mo' | Predicted: Profane | True Label: 1
# Sentence: 'tangina talaga ng bayarin sa bestlink college of the philippines wala akong nakuhang libro pero may notary na punyeta wala naman kaming pinirmahan na kahit anong kasunduan bwiset' | Predicted: Profane | True Label: 1
# Sentence: 'mahalaga paba ang bayaran na babae na sumira sa iyong binuong pamilya parang tanga ang kanta na yan' | Predicted: Profane | True Label: 1
# Sentence: 'aga aga kupal masyado' | Predicted: Profane | True Label: 1
# Sentence: 'may eepal talaga sa tanghali mo eh pakyu ka gagong kyle hindot tarantado' | Predicted: Profane | True Label: 1
# Sentence: 'ulol sino maniniwala sayo' | Predicted: Profane | True Label: 1
# Sentence: 'gigil sayo bwiset haha' | Predicted: Profane | True Label: 1
# Sentence: 'pucha may ganito pa palang regressive na batas ano to panahong kolonyal ng mga amerikano ano to escolta' | Predicted: Profane | True Label: 1
# Sentence: 'tanga ka lasing kana kasi haha' | Predicted: Profane | True Label: 1
# Sentence: 'advice nga nag pakyu sakin yung bata' | Predicted: Profane | True Label: 1
# Sentence: 'tarantado naman oh nawala na naman net' | Predicted: Profane | True Label: 1
# Sentence: 'putangina sinearch ko yung billie torres akala ko artista rin iba lumabas gago naman haha' | Predicted: Profane | True Label: 1
# Sentence: 'tangina mo kung sino ka man' | Predicted: Profane | True Label: 1
# Sentence: 'tarantado pucha haha tanga wag ganon pwede naman natin iinom yan ni mas magastos kasi pag ibuburol ka pa ayusin mo mga desisyon mo sa buhay haha' | Predicted: Profane | True Label: 1
# Sentence: 'pakilinaw kasi bobo ako kapag gabi' | Predicted: Profane | True Label: 1
# Sentence: 'dalawang minuto nalang putangina teka lang huhu' | Predicted: Profane | True Label: 1
# Sentence: 'sagot ko fun tapos sabi nung isang magshishift sa akin ulol haha grabe nagising diwa ko dun' | Predicted: Profane | True Label: 1
# Sentence: 'kanina pa ko dito kila ate tapos yung bayad ganon pa din putangina' | Predicted: Profane | True Label: 1
# Sentence: 'pasensya ka na kupal ako godbless' | Predicted: Profane | True Label: 1
# Sentence: 'oh my gosh sino ka tatay mo kalbo pakyu' | Predicted: Profane | True Label: 1
# Sentence: 'tangina niyo haha pakyu' | Predicted: Profane | True Label: 1
# Sentence: 'tangina naiirita padin ako sa parents nila gago' | Predicted: Profane | True Label: 1
# Sentence: 'tangina deserve mo yan gago' | Predicted: Profane | True Label: 1
# Sentence: 'nanganak na si puta' | Predicted: Profane | True Label: 1
# Sentence: 'wag talaga mag artista pag tarantado ka nung bata ka pa' | Predicted: Profane | True Label: 1
# Sentence: 'pucha yung parang lumilipad lang sa hangin' | Predicted: Profane | True Label: 1
# Sentence: 'ulol umamin ka na wag ka ng mag panggap haha' | Predicted: Profane | True Label: 1
# Sentence: 'putangina hindi pa ako gumagraduate ang dami ko na agad responsibilidad' | Predicted: Profane | True Label: 1
# Sentence: 'iyak na ako dito tangina' | Predicted: Profane | True Label: 1
# Sentence: 'pakialam ko kung wala akong kausap hindi ako pinanganak para intindihin kayong mga tanga kayo' | Predicted: Profane | True Label: 1
# Sentence: 'puta royal cable please huwag ngayon' | Predicted: Profane | True Label: 1
# Sentence: 'coward ka ng coward pero nagmumukhang tanga i mean bobo ka nga' | Predicted: Profane | True Label: 1
# Sentence: 'good thing ba yung lagi akong naka pakyu sa pics mga tita' | Predicted: Profane | True Label: 1
# Sentence: 'master huy na revive si kim kung kelan naging inactive ka pakshet' | Predicted: Profane | True Label: 1
# Sentence: 'ulol gago may pamilya ka na at lahat lahat humanap ka pa ng pokpok' | Predicted: Profane | True Label: 1
# Sentence: 'sabi ko manuod ako run bts eh pakshet itong tiktok eh naubos nanaman oras ko haha' | Predicted: Profane | True Label: 1
# Sentence: 'pakyu hybe ang laki ng mb ng weverse app tapos lag naman' | Predicted: Profane | True Label: 1
# Sentence: 'putangina yung manok ko may pa surprise kat ate bubs puta grabe ka master hindi ka talaga magpapatalo' | Predicted: Profane | True Label: 1
# Sentence: 'yung phone call kasi pucha nakakaiyak' | Predicted: Profane | True Label: 1
# Sentence: 'ayoko na ang sakit na pakshet' | Predicted: Profane | True Label: 1
# Sentence: 'pakyu ka mahal ako ni shoto lol palibhasa di ka mahal ni shoto eh di kase siya nagmamahal ng mga gurang' | Predicted: Profane | True Label: 1
# Sentence: 'tangina sinong may extra polo tangina haha ayaw ko bumili ng bago tapos papalagyan pa ng red seal ah gastos to the max' | Predicted: Profane | True Label: 1
# Sentence: 'ikakahiya ka ng anak mo tanga' | Predicted: Profane | True Label: 1
# Sentence: 'gago andito na sa pinas si billie' | Predicted: Profane | True Label: 1
# Sentence: 'gago excited na talaga ako nextweek haha' | Predicted: Profane | True Label: 1
# Sentence: 'tamang hintay nalang sa another twist kung meron man kung wala edi pakshet kayo revelation' | Predicted: Profane | True Label: 1
# Sentence: 'pakyu ka globe naputol date namin ni valerie' | Predicted: Profane | True Label: 1
# Sentence: 'oo bwiset na bwiset na ko sa kaniya ano ano na sinasabi ko haha' | Predicted: Profane | True Label: 1
# Sentence: 'bagong araw para magpasalamat dahil binigay ng sansinukob ang aking mga kaibigan kahit mga tarantado minsan lagi haha' | Predicted: Profane | True Label: 1
# Sentence: 'tangina ang bilis ko na magka sugat' | Predicted: Profane | True Label: 1
# Sentence: 'haha ulol walang ganon' | Predicted: Profane | True Label: 1
# Sentence: 'putangina alam na tuloy ng teacher namin na nagvavalo ako' | Predicted: Profane | True Label: 1
# Sentence: 'sobrang sama na naman ng pakiramdam ko tangina masama ba ugali ko kaya lagi ako nagkakasakit haha' | Predicted: Profane | True Label: 1
# Sentence: 'kupal ka talaga walang pagbabago sayo' | Predicted: Profane | True Label: 1
# Sentence: 'haha ginawang meme gago' | Predicted: Profane | True Label: 1
# Sentence: 'putangina mixed signals nanaman binibigay tangina tutulog na nga lang ako' | Predicted: Profane | True Label: 1
# Sentence: 'sa mga post ko puro kapekean yun haha ikaw lang gusto ko bobo' | Predicted: Profane | True Label: 1
# Sentence: 'putangina bakit ba pag nagchachat kayo puro kayo wala pucha ano ba ko manghuhula' | Predicted: Profane | True Label: 1
# Sentence: 'sa tamang tao only charot haha pakyu oh' | Predicted: Profane | True Label: 1
# Sentence: 'absent nang absent mga ka duty ko bwiset' | Predicted: Profane | True Label: 1
# Sentence: 'haha gago ka pc lang naman imamine ko' | Predicted: Profane | True Label: 1
# Sentence: 'di ko matulungan taki ko sa mga essay niya hirap maging bobo putangina' | Predicted: Profane | True Label: 1
# Sentence: 'punyeta oo naguguluhan kami' | Predicted: Profane | True Label: 1
# Sentence: 'private naman si kupal' | Predicted: Profane | True Label: 1
# Sentence: 'sure ba kayo na wala pa sa main event gago yung ayuda hanggang next year yung kilig haha' | Predicted: Profane | True Label: 1
# Sentence: 'gago masakit pa rin' | Predicted: Profane | True Label: 1
# Sentence: 'ay ang bobo ko parehas nga pala ng company yung mga grupo na yon' | Predicted: Profane | True Label: 1
# Sentence: 'haha putangina mo marumi ka' | Predicted: Profane | True Label: 1
# Sentence: 'ulol panget mo tanga' | Predicted: Profane | True Label: 1
# Sentence: 'ay bobo di ko nakuha yung simcard ko baka tinext niya ako' | Predicted: Profane | True Label: 1
# Sentence: 'umay sa mindset mong kupal ka' | Predicted: Profane | True Label: 1
# Sentence: 'aba oo bwiset ka' | Predicted: Profane | True Label: 1
# Sentence: 'ulol miss mo nanaman ako haha' | Predicted: Profane | True Label: 1
# Sentence: 'pakyu lumayas ka nandidilim paningin ko sayo' | Predicted: Profane | True Label: 1
# Sentence: 'oh putangina niyong lahat walang lubog lubog sa pamilyang toh' | Predicted: Profane | True Label: 1
# Sentence: 'malupit nga kasi mga abusers ngayon sila na nga kupal at matatapang tapos pag kinausap naman biglang feeling victim' | Predicted: Profane | True Label: 1
# Sentence: 'bwiset ka haha ineencourage ko ngang kausapin ako eh' | Predicted: Profane | True Label: 1
# Sentence: 'bobo ka kung hindi mo alam ang proyekto na yun magbasa ka nasa israel ka ba bakit di ka umuwi maganda na ngayon ang pilipinas' | Predicted: Profane | True Label: 1
# Sentence: 'haha bwiset ka baks' | Predicted: Profane | True Label: 1
# Sentence: 'okay putangina sa pulp na nga lang ako bibili' | Predicted: Profane | True Label: 1
# Sentence: 'isang minuto nalang gago nasan na kagrupo ko huhu' | Predicted: Profane | True Label: 1
# Sentence: 'bakit may masama ba sa single mom kung hindi ka ba naman tanga' | Predicted: Profane | True Label: 1
# Sentence: 'gago maga yung orbital ko pakshet' | Predicted: Profane | True Label: 1
# Sentence: 'feel ko need talaga nating umalis like puta drawing na lang lagi eh' | Predicted: Profane | True Label: 1
# Sentence: 'mga kupal kase haha' | Predicted: Profane | True Label: 1
# Sentence: 'gago hindi ko na kaya' | Predicted: Profane | True Label: 1
# Sentence: 'pangit yung ngiti ko pakshet' | Predicted: Profane | True Label: 1
# Sentence: 'putangina kinakabahan ako sa comeback na to sher' | Predicted: Profane | True Label: 1
# Sentence: 'haha papunta na ako sa exciting part puta pakirot na nang pakirot mga vebs' | Predicted: Profane | True Label: 1
# Sentence: 'pucha ang hapdi ng tiyan ko sa lamig ng shake' | Predicted: Profane | True Label: 1
# Sentence: 'pakshet talaga yang pldt' | Predicted: Profane | True Label: 1
# Sentence: 'yuck punyeta ka pala' | Predicted: Profane | True Label: 1
#
# Evaluation Metrics:
# True Positives (TP): 501
# True Negatives (TN): 496
# False Positives (FP): 5
# False Negatives (FN): 0
# Accuracy: 0.9950
# Precision: 0.9901
# Recall: 1.0000
# F1 Score: 0.9950

# %%
import torch
import pandas as pd

# Initialize counters for metrics calculation
tp = 0  # True Positives
tn = 0  # True Negatives
fp = 0  # False Positives
fn = 0  # False Negatives

# Determine the device for the model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Load CSV file
file_path = '/content/drive/MyDrive/BERT/Testing_Data - Cebuano.csv'  # Replace with your CSV file path
data = pd.read_csv(file_path)

# Loop through the rows of the DataFrame
for index, row in data.iterrows():
    sentence = row['sentence']
    true_label = row['profane']

    # Tokenize the input sentence and move to the appropriate device
    inputs = tokenizer(sentence, return_tensors="pt")
    inputs = {key: val.to(device) for key, val in inputs.items()}  # Move inputs to the same device as the model

    # Perform inference
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits

    # Get the predicted class (0: Not Profane, 1: Profane)
    predicted_class = torch.argmax(logits, dim=-1).item()

    # Update counters
    if predicted_class == 1 and true_label == 1:
        tp += 1  # True Positive
    elif predicted_class == 0 and true_label == 0:
        tn += 1  # True Negative
    elif predicted_class == 1 and true_label == 0:
        fp += 1  # False Positive
    elif predicted_class == 0 and true_label == 1:
        fn += 1  # False Negative

    # Print the result
    if predicted_class == 1:
        print(f"Sentence: '{sentence}' | Predicted: Profane | True Label: {true_label}")
    else:
        print(f"Sentence: '{sentence}' | Predicted: Not Profane | True Label: {true_label}")

# Calculate Precision, Recall, F1-Score, and Accuracy
precision = tp / (tp + fp) if (tp + fp) > 0 else 0
recall = tp / (tp + fn) if (tp + fn) > 0 else 0
f1_score = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn) if (tp + tn + fp + fn) > 0 else 0

# Display evaluation metrics
print("\nEvaluation Metrics:")
print(f"True Positives (TP): {tp}")
print(f"True Negatives (TN): {tn}")
print(f"False Positives (FP): {fp}")
print(f"False Negatives (FN): {fn}")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1_score:.4f}")
# Out:
# Sentence: 'kung di ka mokaon' | Predicted: Not Profane | True Label: 0
# Sentence: 'kinahanglan og pintal sa panimalay nimo' | Predicted: Not Profane | True Label: 0
# Sentence: 'tinuod diay tong hungihong' | Predicted: Not Profane | True Label: 0
# Sentence: 'dili na siya na siya mungisi nako' | Predicted: Not Profane | True Label: 0
# Sentence: 'nagatuo sila sa kinabuhi human sa kamatayon' | Predicted: Not Profane | True Label: 0
# Sentence: 'kanusa nimo siya nakitan nga gisayawan niya siya' | Predicted: Not Profane | True Label: 0
# Sentence: 'wala ko naghunahuna kadiyot nga sayop ka' | Predicted: Not Profane | True Label: 0
# Sentence: 'namatay ang akong lolo sa ikaduhang digmaang kalibutanon' | Predicted: Not Profane | True Label: 0
# Sentence: 'magpakamatay siya inig dili niya makita iyahang anak' | Predicted: Not Profane | True Label: 0
# Sentence: 'gusto ni tatay nga magskwela ko sa laing nasud samtang bata pa ko' | Predicted: Not Profane | True Label: 0
# Sentence: 'nakawala na ko sa akoang tatay' | Predicted: Not Profane | True Label: 0
# Sentence: 'motingog ang kampana inig maalas otso' | Predicted: Not Profane | True Label: 0
# Sentence: 'gisaad sa ginoo nga tanan katawhan mangamatay' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang kamatayan kay murag nagbalhin balhin ra' | Predicted: Not Profane | True Label: 0
# Sentence: 'unsa ba siya tawo' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang katawhan gyud ang mambuhatay ug istorya' | Predicted: Not Profane | True Label: 0
# Sentence: 'dili ko motugot ug kabuang nga natilawan na ko niya' | Predicted: Profane | True Label: 1
# Sentence: 'namatay na tung mga buwaka' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa unang andana sa palasyo kay adunay sayawanan' | Predicted: Not Profane | True Label: 1
# Sentence: 'nakuyawan ko tung nakitan nakong pula ang iyahang buhok' | Predicted: Not Profane | True Label: 1
# Sentence: 'anaa bay tindahan sa hayupan' | Predicted: Not Profane | True Label: 0
# Sentence: 'tinuod nga nakuyawan ko sa balita' | Predicted: Not Profane | True Label: 1
# Sentence: 'fritz ang ngalan sa akong tatay' | Predicted: Not Profane | True Label: 0
# Sentence: 'mamatay ang bulak kon walay tubig' | Predicted: Profane | True Label: 0
# Sentence: 'ang kausaban kay kasabay sa panganak ug kamatayan' | Predicted: Not Profane | True Label: 0
# Sentence: 'dugay nang nangamatay ang mga dinosawro' | Predicted: Not Profane | True Label: 0
# Sentence: 'nakuyawan ko nga naa ka' | Predicted: Not Profane | True Label: 1
# Sentence: 'lisod kaayo ang kinabuhi' | Predicted: Not Profane | True Label: 0
# Sentence: 'wala koy oras anang kamatayon' | Predicted: Not Profane | True Label: 0
# Sentence: 'gihigugma nako ang siningug mga malinawon nga hapon sa panimalay' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang akong igsoon nga lalaki musweldo ug kapin kun kulang katunga sa kita sa akong tatay' | Predicted: Not Profane | True Label: 0
# Sentence: 'mangamatay ang mga tanom kung walay bisbis' | Predicted: Not Profane | True Label: 0
# Sentence: 'mamatay na ba ko dili' | Predicted: Profane | True Label: 0
# Sentence: 'kinahanglan niya nga tunan ang epistemolohiya at ontolohiya' | Predicted: Not Profane | True Label: 0
# Sentence: 'nahibalan nimo nga eksperto ako ug nabuang ka' | Predicted: Profane | True Label: 1
# Sentence: 'hunungi ninyo ang paghisgot bahin sa akong pamilya' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang gibuhat niya kay kabuang' | Predicted: Profane | True Label: 1
# Sentence: 'makamatay kana nga bitin' | Predicted: Not Profane | True Label: 0
# Sentence: 'nahunahunaan niya nga angay to sa buhi ug kamatayon' | Predicted: Not Profane | True Label: 0
# Sentence: 'namatay sa usa ka aksidente ang tulo ka trabahante nga sakay sa trak' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang mga nangamatay lang ang nakakita sa pagkahuman sa giyera' | Predicted: Not Profane | True Label: 0
# Sentence: 'iyang tatay gusto nga mahimo siyang usa ka piyanista' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang tao kay mangamatay' | Predicted: Not Profane | True Label: 0
# Sentence: 'matod pa nila ang talong adunay daghang nikotina' | Predicted: Not Profane | True Label: 0
# Sentence: 'patay na ang tanan nga mga rebelde' | Predicted: Not Profane | True Label: 0
# Sentence: 'naglikay siya nga magistorya bahin sa pagkamatay sa iyang bana' | Predicted: Not Profane | True Label: 0
# Sentence: 'bantayi ang bata alang nako kadiyot' | Predicted: Not Profane | True Label: 0
# Sentence: 'patayon nato ang telebisyon' | Predicted: Not Profane | True Label: 0
# Sentence: 'mahimo ba nimo nga biyaan kami kadiyot' | Predicted: Not Profane | True Label: 0
# Sentence: 'namatay siya sa iyang katre' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang mga tawo nangatulog sa diha nga sila nagpuyo' | Predicted: Not Profane | True Label: 0
# Sentence: 'nahuman nako ang tanan nga buluhaton sa balay ug gusto nako nga mopahulay kadiyot' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang akoang tatay kay naa sa ospital ron' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang ingon nila pedro ug paulo kay mangamatay sad parehas og usa ka martir' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa mga salida nga amerikano' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa pananaw nako kay naboang na ko' | Predicted: Not Profane | True Label: 0
# Sentence: 'namatay ang tigulang ganihang buntag' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang aksidente ang hinungdan sa daghan nga kamatayan' | Predicted: Not Profane | True Label: 0
# Sentence: 'gisulat nako na para sa atoang mga amigo nga nangamatay' | Predicted: Not Profane | True Label: 0
# Sentence: 'gamay na lang ang siyopaw sa kusina' | Predicted: Not Profane | True Label: 0
# Sentence: 'kini ang kwarto kon asa nagpakamatay ang awtor' | Predicted: Not Profane | True Label: 0
# Sentence: 'namatay siya pila ka adlaw pagkahuman sa iyang ikasagatos nga pagselebrar sa iyang pagkatawo' | Predicted: Not Profane | True Label: 0
# Sentence: 'hadlok ko sa kamatayon' | Predicted: Not Profane | True Label: 0
# Sentence: 'usa ka babaye kay nagsuwat og ka libro tungkol sa kon unsaon mahimong malipayon' | Predicted: Not Profane | True Label: 0
# Sentence: 'mas tigulang pa si nanay kay tatay' | Predicted: Not Profane | True Label: 0
# Sentence: 'nagpakamatay si vincent van gogh atong' | Predicted: Not Profane | True Label: 0
# Sentence: 'naay dugo nga asul nga nilatay sa akong mga ugat' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang mga su sa marte kay mga kahayopan nga gikan sa tiyera' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang ilahang pinulungan sama sa pinulungan sa mga kulubot' | Predicted: Not Profane | True Label: 0
# Sentence: 'nag letseplan si binda sa kusina' | Predicted: Not Profane | True Label: 0
# Sentence: 'pangaon mo og letseplan didto sa kusina' | Predicted: Not Profane | True Label: 0
# Sentence: 'maayo ang iyang siyopaw' | Predicted: Not Profane | True Label: 0
# Sentence: 'lami ang siyopaw ni esmeraldo' | Predicted: Not Profane | True Label: 0
# Sentence: 'ayaw sulayi sa panimalay kung unsa man ang inyong mga nakita' | Predicted: Not Profane | True Label: 0
# Sentence: 'nisulti ang isa ka babae' | Predicted: Not Profane | True Label: 0
# Sentence: 'siyopaw na bolabola ang ganahan ni wanda' | Predicted: Not Profane | True Label: 0
# Sentence: 'og asadong siyopaw ang ganahan ni larry' | Predicted: Not Profane | True Label: 0
# Sentence: 'gi tudloan ko sa akong tatay mag luto' | Predicted: Not Profane | True Label: 0
# Sentence: 'gi hungit ni trixie and isa ka kutsarita na maja blanca sa iyang anak na lalake' | Predicted: Not Profane | True Label: 0
# Sentence: 'gi hungit ni alex ang espasol sa iyang baba' | Predicted: Not Profane | True Label: 0
# Sentence: 'wala akong anumang nalalaman sa pinaggagawa ng tatay ko' | Predicted: Not Profane | True Label: 0
# Sentence: 'dili ko naga sulob ug sapatos sa sulud sa akoang panimalay' | Predicted: Not Profane | True Label: 0
# Sentence: 'nagpahuway lang kadiyot dayon nagluto alang sa panihapon' | Predicted: Not Profane | True Label: 0
# Sentence: 'makasabot siya sa dili masabtan sa uban' | Predicted: Not Profane | True Label: 0
# Sentence: 'sigeg kamatay ang mga iro' | Predicted: Not Profane | True Label: 0
# Sentence: 'namatay akong lolo tulo ka tuig na ang milabay' | Predicted: Not Profane | True Label: 0
# Sentence: 'namatay siya sa edad nga sitenta' | Predicted: Not Profane | True Label: 0
# Sentence: 'kanunaya nga hinlo ang inyong panimalay' | Predicted: Not Profane | True Label: 0
# Sentence: 'dili ko makaingon nga nakuyawanko' | Predicted: Not Profane | True Label: 1
# Sentence: 'nisaka og mga napulo kaporsyento ang ihap sa depresyon ilabina ang pagpakamatay sa nialabay nga pulo ka tuig' | Predicted: Not Profane | True Label: 0
# Sentence: 'gihungitan ni danny ang bata og biko' | Predicted: Not Profane | True Label: 0
# Sentence: 'ginahungitan ni danny ang bata og biko' | Predicted: Not Profane | True Label: 0
# Sentence: 'hungitan ni danny ang bata og biko' | Predicted: Not Profane | True Label: 0
# Sentence: 'gihungitan sa amahan ang bata og biko' | Predicted: Not Profane | True Label: 0
# Sentence: 'ginahungitan sa amahan ang bata og biko' | Predicted: Not Profane | True Label: 0
# Sentence: 'daghang siyopaw si silvestre sa balay niya' | Predicted: Not Profane | True Label: 0
# Sentence: 'kung tirahon ka og bato' | Predicted: Not Profane | True Label: 0
# Sentence: 'nangamatay ang mga kahoy' | Predicted: Not Profane | True Label: 0
# Sentence: 'nagbangotan si carla sa pagkamatay sa iyang iro ang akong kasingkasing naguba pagusab' | Predicted: Not Profane | True Label: 0
# Sentence: 'daghan ang gibunot ni alden sa bagong naandan nga pagshooting sa gma christmas station id' | Predicted: Not Profane | True Label: 0
# Sentence: 'mananom sila tatay ug mais sa pikas bukid' | Predicted: Not Profane | True Label: 0
# Sentence: 'mogahi ang lawas inigkamatay' | Predicted: Not Profane | True Label: 0
# Sentence: 'nagkadako ang gamaw sa submarino' | Predicted: Not Profane | True Label: 0
# Sentence: 'abi kog nahigugma ka kanako' | Predicted: Not Profane | True Label: 0
# Sentence: 'tingali ang pagkabuang sumbanon sa imong pamilyaha' | Predicted: Profane | True Label: 1
# Sentence: 'karon gisumpong siya sa iyang kabuang na pod' | Predicted: Profane | True Label: 1
# Sentence: 'gibuang ko sa bugsikan' | Predicted: Profane | True Label: 1
# Sentence: 'ang sayong kamatayon lang napugnan sa katigulangon' | Predicted: Not Profane | True Label: 0
# Sentence: 'may tigulang nga babae nga gisunog sa kamatayon' | Predicted: Not Profane | True Label: 0
# Sentence: 'makapasubo nako ang maghunahuna sa iyang kamatayon' | Predicted: Not Profane | True Label: 0
# Sentence: 'patay ba o buhi pa ang bagtok' | Predicted: Not Profane | True Label: 0
# Sentence: 'kaliwat ko og zamboanggahanon' | Predicted: Not Profane | True Label: 0
# Sentence: 'nabuang na sila nimo' | Predicted: Profane | True Label: 1
# Sentence: 'hingkod na ang panahon sa panimalus' | Predicted: Not Profane | True Label: 0
# Sentence: 'binuang ang pagpakamatay tungod sa kahadlok sa mga migrante' | Predicted: Not Profane | True Label: 0
# Sentence: 'linibo nay nangamatay tungod sa pagpanghasi' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang buhatan ni rosi sa pampaman' | Predicted: Not Profane | True Label: 0
# Sentence: 'nagpampam lang si rosi kay gusto siya ug kwartang sayon' | Predicted: Not Profane | True Label: 0
# Sentence: 'nagpakaburikat lang si rosi kay gustog sayon nga kwarta' | Predicted: Not Profane | True Label: 0
# Sentence: 'sayo nga kamatayon lang magpugong sa katigulangon' | Predicted: Not Profane | True Label: 0
# Sentence: 'nagpampam siya kay gusto siya ug kwartang sayon' | Predicted: Not Profane | True Label: 0
# Sentence: 'mogahi ang lawas inigkamatay' | Predicted: Not Profane | True Label: 0
# Sentence: 'nagkadako ang gamaw sa submarino' | Predicted: Not Profane | True Label: 0
# Sentence: 'tingali ang pagkabuang sumbanon sa imong pamilyaha' | Predicted: Profane | True Label: 1
# Sentence: 'karon gisumpong siya sa iyang kabuang na pod' | Predicted: Profane | True Label: 1
# Sentence: 'gibuang ko sa bugsikan' | Predicted: Profane | True Label: 1
# Sentence: 'ang sayong kamatayon lang napugnan sa katigulangon' | Predicted: Not Profane | True Label: 0
# Sentence: 'sayo nga kamatayon lang magpugong sa katigulangon' | Predicted: Not Profane | True Label: 0
# Sentence: 'hingkod na ang panahon sa panimalus' | Predicted: Not Profane | True Label: 0
# Sentence: 'binuang ang pagpakamatay tungod sa kahadlok sa mga migrante' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang buhatan ni rosi sa pampaman' | Predicted: Not Profane | True Label: 0
# Sentence: 'nagpampam lang si rosi kay gusto siya ug kwartang sayon' | Predicted: Not Profane | True Label: 0
# Sentence: 'nagpampam siya kay gusto siya ug kwartang sayon' | Predicted: Not Profane | True Label: 0
# Sentence: 'mananom sila tatay ug mais sa pikas bukid' | Predicted: Not Profane | True Label: 0
# Sentence: 'tatay mo ba siya' | Predicted: Not Profane | True Label: 0
# Sentence: 'mamahuway ta ug kadiyotkadali' | Predicted: Not Profane | True Label: 0
# Sentence: 'daghang tawong nangamatay sa linog' | Predicted: Not Profane | True Label: 0
# Sentence: 'patay kadto nga tawo' | Predicted: Not Profane | True Label: 0
# Sentence: 'giayos ni tatay ang sakyanan' | Predicted: Not Profane | True Label: 0
# Sentence: 'patay na siya napulo na ka tuig ang nilabay' | Predicted: Not Profane | True Label: 0
# Sentence: 'mihunong ang musika kadiyot' | Predicted: Not Profane | True Label: 0
# Sentence: 'namatay na kadtong mga bulak' | Predicted: Not Profane | True Label: 0
# Sentence: 'mamatay ang tanum nga walay tubig' | Predicted: Profane | True Label: 0
# Sentence: 'ug miingon ang dios magpatubo ang yuta ug mga binuhat nga buhi ingon sa ilang matang' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug gibuhat sa dios ang mga mananap sa yuta ingon sa ilang matang' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug miingon ang dios buhaton nato ang tawo sumala sa atong dagway' | Predicted: Not Profane | True Label: 0
# Sentence: 'apan sa kahoy nga sa pagila sa maayo ug sa dautan' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug gihatagan ni adam ug mga ngalan ang tanan nga kahayopan ug ang mga langgam sa kalangitan ug ang tanan nga mga mananap sa kapatagan apan alang kang adam walay hingkaplagan nga katabang nga angay kaniya' | Predicted: Not Profane | True Label: 0
# Sentence: 'apan sa bunga sa kahoy nga anaa sa taliwala sa tanaman' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si jehova nga dios nagingon sa bitin tungod kay ikaw nagbuhat niini' | Predicted: Not Profane | True Label: 0
# Sentence: 'ania karon ginaabug mo ako niining adlawa gikan sa nawong sa yuta' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si ada nanganak kang jabal' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si lamech miingon sa iyang mga asawa ada ug zilla' | Predicted: Not Profane | True Label: 0
# Sentence: 'kong sa pito ka pilo pagapanimalusan si cain' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug giila pagusab ni adam ang iyang asawa' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang tanan nga mga adlaw sa kinabuhi ni adam siyam ka gatus ug katloan ka tuig' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang tanan nga mga adlaw ni seth siyam ka gatus ug napulo ug duha ka tuig' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang tanan nga mga adlaw ni enos' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang tanan nga mga adlaw ni cainan siyam ka gatus ug napulo ka tuig' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang tanan nga mga adlaw ni mahalaleel' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang tanan nga mga adlaw ni jared siyam ka gatus kanuman ug duha ka tuig' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang tanan nga mga adlaw ni mathusalam siyam ka gatus kanuman ug siyam ka tuig' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si jehova miingon kang noe sumulod ka ug ang tibook mong panimalay sa arca kay ikaw nakita ko nga matarung sa akong atubangan niining kaliwatana' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug nangamatay ang tanan nga unod nga nagalihok sa ibabaw sa yuta' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang tanan nga may gininhawa sa espiritu sa kinabuhi sa ilang mga ilong' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug gilaglag ang tanang butang nga may kinabuhi sa ibabaw sa nawong sa yuta' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug nahinumdum ang dios kang noe ug sa tanan nga mga mananap ug sa tanang kahayupan nga didto uban kaniya sa arca' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ipagula mo uban kanimo ang tanan nga mga mananap nga anaa uban kanimo' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug sa tanan nga binuhat nga buhi nga anaa uban kaninyo' | Predicted: Not Profane | True Label: 0
# Sentence: 'tungod niini kanila gibahinbahin ang kapupudan sa mga nasud sa ilang mga yuta' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang mga adlaw ni tare duha ka gatus ug lima ka tuig' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug siya nagbuhat ug maayo kang abram tungod kaniya ug siya may mga carnero' | Predicted: Not Profane | True Label: 0
# Sentence: 'apan gihampak ni jehova si faraon ug ang iyang panimalay pinaagi sa dagkung mga hampak' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si abram dato kaayo sa kahayupan' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug dihay pagkabingkil sa mga magbalantay sa kahayupan ni abram ug sa mga magbalantay sa kahayupan ni lot' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug sa tuig nga ikapulo ug upat miabut si chedorlaomer' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug sila gibahinbahin niya sa kagabhion' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug mitubag si abram o' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si abram miingon ania karon' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si sarai nga asawa ni abram' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ihatag ko kanimo ug sa imong kaliwatan sa ulahi nimo' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug magkuha ako ug usa ka hungit nga tinapay' | Predicted: Not Profane | True Label: 0
# Sentence: 'kay siya naila ko' | Predicted: Not Profane | True Label: 0
# Sentence: 'apan ang dios miadto kang abimelech nga sa damgo sa kagabhion ug siya miingon kaniya tanawa' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug kong dili mo pagiuli siya' | Predicted: Not Profane | True Label: 0
# Sentence: 'kay giserhan gayud ni jehova ang tanan nga taguangkan sa panimalay ni abimelech tungod kang sara nga asawa ni abraham' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug gituyod ni abraham ang iyang kamot' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug mitindog si abraham sa atubangan sa iyang minatay' | Predicted: Not Profane | True Label: 0
# Sentence: 'lumalangyaw ug dumuloong ako sa taliwala ninyo hatagi ako ninyo ug panulondon nga lubnganan uban kaninyo ug pagalubnganan ko sa akong minatay halayo sa akong mga mata' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug siya misulti kanila nga nagaingon kong kamo may kabubuton nga ako magalubong sa akong minatay bulag sa akong mata' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug mitubag siya kang ephron' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug siya miingon kanako si jehova' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug gipasulod siya ni isaac ngadto sa balongbalong sa iyang inahan nga si sara' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug gitugyan ni abraham ang espiritu' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug nahitabo sa tapus ang kamatayon ni abraham' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug kini sila mao ang mga anak nga lalake ni ismael' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug kini mao ang mga tuig sa kinabuhi ni ismael' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si isaac mitubag kaniya' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug nakapanagiya siya sa mga panon sa mga carnero' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug gikalot pagusab ni isaac ang mga atabay sa tubig' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang mga magbalantay sa kahayupan sa gerar nanagpakigaway sa mga magbalantay sa kahayupan ni isaac' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si isaac mipatindog didto ug usa ka halaran' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug miingon siya tanawa karon' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug buhatan mo ako ug makaon nga lamian' | Predicted: Not Profane | True Label: 0
# Sentence: 'dadan mo ako nganhi ug inayaman' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug dadon mo kini sa imong amahan' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug gisuginlan si rebeca sa mga pulong ni esau nga iyang anak nga kamagulangan ug iyang gipasugoan ug gipatawag si jacob nga anak niya nga kamanghuran' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug miingon siya tanawa' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug sa pagtanaw ni raquel nga siya wala makahatag ug mga anak kang jacob' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si jacob nasuko batok kang raquel' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug siya mitubag kaniya ikaw nahibalo kong unsa ang pagalagad ko kanimo' | Predicted: Not Profane | True Label: 0
# Sentence: 'kay diriyut pa ang imo' | Predicted: Not Profane | True Label: 0
# Sentence: 'moadto ako karon sa tanan mong panon sa mga carnero' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug gilain niya niadtong adlawa ang mga lake nga kanding nga binugkan' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug gibutang niya ang mga sanga nga magagmay nga iyang gipanitan didto sa atbang sa kahayupan sa pasungan nga paimnanan' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa ingon niini gikuha sa dios ang kahayupan sa imong amahan' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug iyang gidala ang iyang tanan nga kahayupan' | Predicted: Not Profane | True Label: 0
# Sentence: 'diha ako magpuyo sa imong balay sulod sa kaluhaan ka tuig napulo ug upat ka tuig ako nagalagad kanimo tungod sa imong duruha ka mga anak nga babaye' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ako adunay mga vaca' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug siya miingon kaniya ang akong ginoo nahibalo nga ang mga bata mga linghud' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si jacob migikan padulong sa succoth' | Predicted: Not Profane | True Label: 0
# Sentence: 'karon nakadungog si jacob nga si dina anak niya nga babaye gihugawan ni sichem ug ang iyang mga anak nga lalake didto sa iyang kahayupan sa kapatagan ug si jacob nagpakahilum lamang hangtud nga sila nangabut' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang batanong lalake wala maglangan sa pagbuhat niadto' | Predicted: Not Profane | True Label: 0
# Sentence: 'dili ba ang ilang kahayupan ug ang ilang bahandi' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug nahitabo sa ikatolo ka adlaw' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang mga anak nga lalake ni jacob nangadto sa mga nangamatay ug nanagpanulis sila sa lungsod tungod kay gihugawan nila ang ilang igsoon nga babaye' | Predicted: Not Profane | True Label: 0
# Sentence: 'unya miingon si jacob kang simeon ug kang levi nagpagubut kamo kanako sa pagbuhat kanako nga dinumtan sa mga pumoluyo niining yutaa' | Predicted: Not Profane | True Label: 0
# Sentence: 'unya si jacob miingon sa iyang panimalay' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang mga anak nga lalake ni bilha' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang mga anak nga lalake ni zilpa' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug mihalin ang espiritu ni isaac' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug gidala ni esau ang iyang mga asawa' | Predicted: Not Profane | True Label: 0
# Sentence: 'kay ang ilang bahandi daku da kong magusa sila sa pagpuyo' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang iyang mga igsoon nanagpangadto sa pagpasibsib sa kahayupan sa ilang amahan sa sichem' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug siya miingon kaniya umadto ka karon' | Predicted: Not Profane | True Label: 0
# Sentence: 'apan siya hingkitan nila didto sa halayo' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug miingon kanila si ruben dili kamo magpatulo ug dugo ihulog siya niining gahong nga anaa sa kamingawan' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug sa miagi ang daghang mga adlaw' | Predicted: Not Profane | True Label: 0
# Sentence: 'siya dili labaw kay kanako niining balaya' | Predicted: Not Profane | True Label: 0
# Sentence: 'ikaw magagahum sa akong panimalay' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug gihinganlan ni jose ang ngalan sa panganay si manases kay' | Predicted: Not Profane | True Label: 0
# Sentence: 'kong kamo mga tawo nga matuod' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug dadon ninyo dinhi kanako ang inyong igsoon nga lalake nga kamanghuran sa ingon niana' | Predicted: Not Profane | True Label: 0
# Sentence: 'ipadala uban kanako ang bata ug manindog ug mangadto kami' | Predicted: Not Profane | True Label: 0
# Sentence: 'kong kinsa sa imong mga ulipon nga kaniya hikaplagan ang copa' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug kami mingtubag sa akong ginoo aduna kami ing amahan nga tigulang' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug kami mingingon sa akong ginoo ang batanon dili arang makabiya sa iyang amahan' | Predicted: Not Profane | True Label: 0
# Sentence: 'mahitabo nga kong dili niya makita ang bata uban kanamo' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug siya nagminatay sa paghilak ug nanagpakadungog ang mga egiptohanon' | Predicted: Not Profane | True Label: 0
# Sentence: 'busa karon wala kamo magpadala kanako dinhi' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug magapuyo ka sa yuta sa gosen' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug didto pagapakanon ko ikaw' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug miingon si faraon kang jose ingna ang imong mga igsoon buhata ninyo kini luwanan ninyo ang inyong mga hayupan' | Predicted: Profane | True Label: 0
# Sentence: 'ug kuhaa ninyo ang inyong amahan' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ilang gidala ang ilang kahayupan' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang mga anak nga lalake ni juda si er' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si jose miingon sa iyang mga igsoon nga lalake ug sa panimalay sa iyang amahan moadto ako ug magpahibalo ako kang faraon' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang akong mga igsoon nga lalake' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang mga tawo mga magbalantay sa mga carnero' | Predicted: Not Profane | True Label: 0
# Sentence: 'nga magaingon kamo ang imong mga ulipon mga magbabaton sa kahayupan gikan pa sa among pagkabata hangtud karon' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ginapakaon ni jose ug tinapay ang iyang amahan ug ang iyang mga igsoon nga lalake' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug sa nahurot na ang salapi sa yuta sa egipto' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si jose miingon ihatag ninyo ang inyong kahayupan' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ilang gidala ang ilang kahayupan ngadto kang jose ug si jose mihatag kanila ug mga makaon nga baylo sa mga kabayo' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug sa tapus ang tuig' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug mahitabo nga sa panahon sa tingani ihatag ninyo ang ikalima ka bahin kang faraon' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug nagkahaduol na ang mga adlaw sa pagkamatay ni israel' | Predicted: Not Profane | True Label: 0
# Sentence: 'apan mahitungod kanako sa paggikan ko sa padanaram' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug miingon si israel kang jose ania karon' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug sa miagi na ang mga adlaw sa pagbalata alang kaniya' | Predicted: Not Profane | True Label: 0
# Sentence: 'gipapanumpa ako sa akong amahan' | Predicted: Not Profane | True Label: 0
# Sentence: 'unya si jose mitungas sa paglubong sa iyang amahan ug mitungas uban kaniya ang tanang mga ulipon ni faraon' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang tibook nga panimalay ni jose' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug midangat sila sa yuta sa atad nga pagagiukan sa trigo' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug mipuyo si jose sa egipto' | Predicted: Not Profane | True Label: 0
# Sentence: 'mao kini ang mga ngalan sa mga anak ni israel' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug nahitabo tungod kay ang mga mananabang nahadlok sa dios' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug siya mitanaw dinhi ug didto' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug sa hingdunggan ni faraon kini nga butanga' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug nangabut ang mga magbalantay sa kahayupan' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si jehova miingon kang moises didto sa median lumakaw ka' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug nahatabo didto sa dalan sa usa ka balay nga abutanan nga migula si jehova nga misugat kaniya' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug sila miingon ang dios sa mga hebreohanon nakigkita kanamo nangaliyupo kami kanimo' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug sila mingingon kanila si jehova magtanaw unta sa ibabaw ninyo' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si jehova miingon kang moises karon makita mo kong unsay buhaton ko kang faraon kay pinaagi sa kamot nga kusgan magatugot siya sa pagpalakat kanila' | Predicted: Not Profane | True Label: 0
# Sentence: 'kini mao ang mga pangulo sa mga panimalay sa ilang mga ginikanan ang mga anak nga lalake ni ruben' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang mga anak nga lalake ni cora si aser ug si elcana' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang mga isda nga anaa sa suba mangamatay' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang mga isda nga diha sa suba nangamatay ug ang suba naglangog' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si jehova nagbuhat sumala sa pulong ni moises' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si faraon misugo ug ania karon' | Predicted: Not Profane | True Label: 0
# Sentence: 'kay karon gibakyaw ko ang akong kamot ug gihampak ikaw' | Predicted: Not Profane | True Label: 0
# Sentence: 'siya nga nahadlok sa pulong ni jehova sa kinataliwadan sa mga sulogoon ni faraon' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug siya nga wala magtagad sa pulong ni jehova' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang among kahayupan magauban usab kanamo walay mahabilin bisan usa ka koko kay kanila magkuha kami sa among pagalagad kang jehova nga among dios ug kami wala mahibalo kong uban sa unsang butanga kinahanglan kami magalagad kang jehova' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si faraon miingon kaniya pahawa ka kanako magbantay ka sa imong kaugalingon nga dili ka na makakita sa akong nawong' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang tanan nga panganay sa yuta sa egipto mangamatay' | Predicted: Not Profane | True Label: 0
# Sentence: 'magsulti kamo s atibook nga katilingban sa israel nga magaingon sa ikapulo niining bulana sila magakuha ang tagsatagsa ug usa ka nating carnero sumala sa gidaghanon sa mga panimalay sa ilang mga amahan' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug kong ang panimalay diriyut da nga dili makahurot sa pagkaon sa usa ka nating carnero' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang dugo timaan sa mga balay diin kamo magapuyo ug kong makita ko ang dugo molabay ako sa ibabaw kaninyo' | Predicted: Not Profane | True Label: 0
# Sentence: 'unya si moises mitawag sa tsanan nga mga anciano sa israel' | Predicted: Not Profane | True Label: 0
# Sentence: 'kamo managpanubag mao kini ang halad sa pasko ni jehova nga milabay ibabaw sa mgsa balay sa mga anak sa israel didto sa egipto' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug mibangon niadtong gabhiona si faraon' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang mga egiptohanon nagpilit sa katawohan aron sa madali manggula sila sa yuta kay sila nanagingon kami mangamatay nga tanan' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug mipanaw usab uban kanila ang nagakasagul nga panon sa katawohan' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug nahitabo nga si faraon sa halus motugot kanamo sa pagpalakaw' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug miingon sila kang moises tungod ba kay walay mga lubnganan sa egipto' | Predicted: Not Profane | True Label: 0
# Sentence: 'dili ba kini mao nga ginasulti namo kanimo sa egipto nga nagaingon pasagdi lamang kami nga magaalagad sa mga egiptohanon kay labing maayo pa kanamo ang pagalagad sa mga egiptohanon' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang panimalay sa israel naghingalan niini nga mana ug kini maingon sa liso sa culantro' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang katawohan giuhaw sa tubig ug ang katawohan nagbagulbol batok kang moises' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug miingon si moises kang josue pagpili gikan kanato ug mga tawo ug gumula ka' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si moises mitungas ngadto sa dios' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si jehova miingon kang moises lumugsong ka ug sugoon mo ang katawohan tingali unya molabang sila sa utlanan sa pagtutok kang jehova' | Predicted: Not Profane | True Label: 0
# Sentence: 'apan ang adlaw nga ikapito maoy usa ka adlaw nga igpapahulay alang kang jehova nga imong dios niining adlawa dili ka magbuhat' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug miingon sila kang moises makigsulti ka kanamo' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug kong ang usa ka tawo magapalabilabi batok sa iyang isigkatawo' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug kong may mga tawo nga managaway' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug kong ang usa ka tawo magasamad sa iyang ulipon nga lalake kun sa iyang ulipon nga babaye uban sa bunal' | Predicted: Not Profane | True Label: 0
# Sentence: 'kong ang usa ka lalake kun usa ka babaye pagasungayon sa usa ka vaca' | Predicted: Not Profane | True Label: 0
# Sentence: 'apan kong ang maong vaca adunay batasan sa pagsungay sukad pa sa miaging panahon' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug kong ang vaca sa usa ka tawo makasamad sa vaca sa iyang isigkatawo' | Predicted: Not Profane | True Label: 0
# Sentence: 'apan kong hibaloan nga ang vaca nga nakasungay adunay taras sa pagpanungay sukad pa sa miaging panahon' | Predicted: Not Profane | True Label: 0
# Sentence: 'kong ang kawatan hikaplagan nga nagaguba aron makasulod sa usa ka balay' | Predicted: Not Profane | True Label: 0
# Sentence: 'kong ang adlaw misubang na sa ibabaw niya' | Predicted: Not Profane | True Label: 0
# Sentence: 'kong ang usa ka tawo magapasibsib sa uma kun parrasan' | Predicted: Not Profane | True Label: 0
# Sentence: 'kong ang usa ka tawo makatugyan sa iyang isigkatawo ug asno' | Predicted: Not Profane | True Label: 0
# Sentence: 'magpahilayo ka sa mga buruka nga malimbongon' | Predicted: Not Profane | True Label: 0
# Sentence: 'apan sa ikapito ka tuig pagabiyaan mo kini nga walay pugas ug pasagdan mo' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug kini anha sa ibabaw ni aaron kong siya magaalagad ug hidunggan ang tingog niini kong siya magasulod sa dapit nga balaan sa atubangan ni jehova' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug igasulob kini kang aaron ug sa iyang mga anak nga lalake kong sila mosulod sa balongbalong nga pagatiguman' | Predicted: Not Profane | True Label: 0
# Sentence: 'unya kuhaon mo ang tambok sa carnero nga lake' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa diha nga ikaw magkuha sa padron sa mga anak sa israel ingon sa mga giisip gikan kanila' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug sa diha nga magasulod sila sa balongbalong nga pagatiguman' | Predicted: Not Profane | True Label: 0
# Sentence: 'kay ngano ba nga magasulti ang mga egiptohanon' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang tanan nga nagabuka sa taguangkan maako ug ang tanan nga lake sa imong kahayupan' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang tabil sa pultahan sa sawang maoy buhat sa magbobolda' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug nagbuhat sila ug duruha ka singsing nga bulawan' | Predicted: Not Profane | True Label: 0
# Sentence: 'apan kong ang panganod wala pagbayawa' | Predicted: Not Profane | True Label: 1
# Sentence: 'magsulti ka sa mga anak sa israel' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug kong ang iyang halad gikan sa kahayupan' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang duruha ka amimislon ug ang tambok nga anaa sa ibabaw nila' | Predicted: Not Profane | True Label: 0
# Sentence: 'apan kong ang iyang halad nga sa haladsapakigdait alang kang jehova kinuha sa panon sa kahayupan bisan lake kun baye' | Predicted: Not Profane | True Label: 0
# Sentence: 'ingon usab ang duruha ka amimislon ug ang tambok nga anaa sa ibabaw nila' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang duruha ka amimislon' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang duruha ka mga amimislon ug ang tambok nga anaa sa ibabaw nila' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug igabutang niya ang iyang kamot sa ibabaw sa ulo sa kanding nga lake' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug igabutang niya ang iyang kamot sa ibabaw sa ulo sa haladtungodsasala' | Predicted: Not Profane | True Label: 0
# Sentence: 'o kong may tawo nga makahikap sa bisan unsang butanga nga mahugaw' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug gikuha niya ang tanan nga tambok nga diha sa ibabaw sa mga tinae' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug gikuha niya ang tambok ug ang ikog nga matambok' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug sa pultahan sa balongbalong nga pagatiguman magpuyo kamo sa adlaw ug sa gabii sulod sa pito ka adlaw' | Predicted: Not Profane | True Label: 0
# Sentence: 'apan ang tambok ug ang mga amimislon' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug gihalad niya ang halad sa katawohan' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang mga tambok sa vaca' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug may migula nga kalayo gikan sa atubangan ni jehova' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si moises miingon kang aaron' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug dili manggula sa pultahan sa balongbalong nga pagatiguman' | Predicted: Not Profane | True Label: 0
# Sentence: 'ikaw ug ang imong mga anak nga lalake uban kanimo' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa unod niini dili kamo magkaon' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug kini mahimong dulumtanan alang kaninyo sa ilang unod dili kamo mangaon' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug tungod niining mga butanga' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang bisan unsa nga nagalakaw sa lapalapa sa tiil' | Predicted: Not Profane | True Label: 0
# Sentence: 'apan kong butangan ug tubig ang binhi' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug kong ang buhok sa usa ka lalake mangalarot' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug kong ang buhok dapit sa iyang agtang mangalarot' | Predicted: Not Profane | True Label: 0
# Sentence: 'apan kong diha sa naupawan kun sa naupawan sa agtang may sakit nga maputi nga mapulapula' | Predicted: Not Profane | True Label: 0
# Sentence: 'unya ang sacerdote magahiling kaniya' | Predicted: Not Profane | True Label: 0
# Sentence: 'mahitungod sa langgam nga buhi' | Predicted: Not Profane | True Label: 0
# Sentence: 'unya ang tagiya sa balay' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug pagakuptan niya ang kahoy nga cedro' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa ingon niana pagapabulagon mo ang mga anak sa israel gikan sa ilang pagkahugaw' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si jehova misulti kang moises sa tapus mangamatay ang duruha ka anak nga lalake ni aaron' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si jehova miingon kang moises ingna si aaron nga imong igsoon nga lalake nga sa tanan nga panahon dili siya magsulod sa dapit nga balaan' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug igahalad ni aaron ang lakeng vaca alang sa haladtungodsasala' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug igahalad ni aaron ang lakeng vaca nga mao ang haladtungodsasala alang kaniya' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug igabutang niya ang incienso sa ibabaw sa kalayo sa atubangan ni jehova' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug walay bisan kinsa nga tawo sa sulod sa balongbalong nga pagatiguman kong siya mosulod sa pagbuhat sa pagtabonsasala didto sa dapit nga balaan' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug dili ninyo pagsamaran ang inyong unod tungod sa usa ka minatay' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug kong ang mga tawo sa yuta magatago gayud sa ilang mga mata gikan niadtong tawohana' | Predicted: Not Profane | True Label: 0
# Sentence: 'nan ako magabutang sa akong nawong batok niadtong tawohana' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug kong ang usa ka tawo mohigda ipon sa asawa sa iyang uyoan' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si jehova miingon kang moises isulti mo sa mga sacerdote' | Predicted: Not Profane | True Label: 0
# Sentence: 'dili sila magapaupaw sa ilang ulo ni magagil sa nasikuhan sa ilang bungot' | Predicted: Not Profane | True Label: 0
# Sentence: 'bisan kinsa nga tawohana sa kaliwatan ni aaron' | Predicted: Not Profane | True Label: 0
# Sentence: 'busa pagabantayan nila ang akong katungdanan tingali hinoon ug makasala sila tungod niini' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug siya nga makasamad nga ikamatay sa bisan kinsa nga tawohana' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug pagabalaanon ninyo ang ikakaliman ka tuig' | Predicted: Not Profane | True Label: 0
# Sentence: 'unya siya mopahawa kanimo' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug kong usa ka lumalangyaw kun dumuloong nga anaa uban kanimo' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang mga mananap nga mapintas igapadala ko sa inyong taliwala' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug pagadadan ko kamo ug espada nga magapanimalus sa paglalis sa akong tugon ug pagatigumon kamo sa inyong mga lungsod ug ako magapadala ug kamatay sa taliwala ninyo' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug pagalaglagon ko ang inyong mga hatagas nga dapit' | Predicted: Not Profane | True Label: 0
# Sentence: 'magkuha kamo ug padron sa tibook nga katilingban sa mga anak sa israel pinaagi sa ilang mga panimalay' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang mga anak ni ruben' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa mga anak ni simeon pinaagi sa ilang kaliwatan' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa mga anak ni gad' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa mga anak ni juda' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa mga anak ni issachar' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa mga anak ni zabulon sa ilang mga kaliwatan' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa mga anak ni jose sa mga anak ni ephraim' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa mga anak ni manases' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa mga anak ni benjamin' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa mga anak ni dan' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa mga anak ni aser' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa mga anak ni nephtali' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa ingon niana ang mga anak sa israel nagbuhat sumala sa tanan nga gisugo ni jehova kang moises niini nagpahamutang sila pinaagi sa ilang mga bandila' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug si nadab ug si abiu nangamatay sa atubangan ni jehova' | Predicted: Not Profane | True Label: 0
# Sentence: 'kay ang tanang mga panganay ako man sa adlaw sa pagpamatay ko sa tanang mga panganay didto sa yuta sa egipto' | Predicted: Not Profane | True Label: 0
# Sentence: 'isipon mo ang anak ni levi pinaagi sa mga balay sa ilang mga amahan pinaagi sa ilang mga panimalay nga pagaisipon mo ang tanang mga lalake sukad sa usa pa ka bulan ang panuigon ug ngadto sa itaas' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug kini mao ang mga ngalan sa mga anak nga lalake ni gerson' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang mga anak nga lalake ni coath pinaagi sa ilang mga panimalay si amran' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang mga anak nga lalake ni merari pinaagi sa ilang mga panimalay si mahali' | Predicted: Not Profane | True Label: 0
# Sentence: 'kang gerson mao ang panimalay no libni' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang mga panimalay ni gerson magapahamutang sa ilang mga balongbalong sa likod sa tabernaculo' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang panimalay sa mga anak nga lalake ni coath magapahaluna sa kiliran sa tabernaculo ngadto sa habagatan' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang principe sa balay sa amahan sa mga panimalay ni coath' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug ang principe sa balay sa amahan sa mga panimalay ni merari' | Predicted: Not Profane | True Label: 0
# Sentence: 'ang tanang mga naisip sa mga levihanon nga giisip ni moises ug ni aaron' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug kuhaon mo ang mga levihanon alang kanako ako mao si jehova nga salili sa tanang mga panganay sa mga anak sa israel ug ang kahayupan sa mga levihanon nga salili sa tanang panganay sa kahayupan sa mga anak sa israel' | Predicted: Not Profane | True Label: 0
# Sentence: 'kuhaon mo ang mga levihanon nga salili sa tanang mga panganay sa mga anak sa israel' | Predicted: Not Profane | True Label: 0
# Sentence: 'kumuha ka ug padron sa mga anak nga lalake ni coath sa taliwala sa mga anak nga lalake ni levi' | Predicted: Not Profane | True Label: 0
# Sentence: 'ug sa human si aaron ug ang iyang mga anak nga lalake makatabon sa balaang puloyanan' | Predicted: Not Profane | True Label: 0
# Sentence: 'dili ninyo pagipalaglag ang banay sa mga panimalay ni coath gikan sa taliwala sa mga levihanon' | Predicted: Not Profane | True Label: 0
# Sentence: 'apan kini buhaton ninyo aron sila mabuhi' | Predicted: Not Profane | True Label: 0
# Sentence: 'apan dili sila magasulod sa pagtanaw sa balaang puloyanan' | Predicted: Not Profane | True Label: 0
# Sentence: 'kumuha ka usab ug padron' | Predicted: Not Profane | True Label: 0
# Sentence: 'kini mao ang katungdanan sa mga panimalay ni gerson' | Predicted: Not Profane | True Label: 0
# Sentence: 'kini mao ang pagalagad sa mga panimalay sa mga anak nga lalake ni gerson sa sulod sa balongbalong nga pagatiguman' | Predicted: Not Profane | True Label: 0
# ...
# Sentence: 'makasabot siya sa dili masabtan sa uban maong gitawag siyag buang' | Predicted: Profane | True Label: 1
# Sentence: 'nagakaon og leche flan si ziggy' | Predicted: Profane | True Label: 1
# Sentence: 'nagagama og leche flan si ziggy' | Predicted: Profane | True Label: 1
# Sentence: 'gibutanang ni ziggy og leche flan ang keyk' | Predicted: Profane | True Label: 1
# Sentence: 'adunay leche flan sa ibabaw sa keyk ni ziggy' | Predicted: Profane | True Label: 1
# Sentence: 'leche flan ug buko pandan ang gusto kaunon ni ziggy' | Predicted: Profane | True Label: 1
# Sentence: 'wala kay malunit sa upaw' | Predicted: Not Profane | True Label: 1
# Sentence: 'abi kog nahigugma ka kanako sa tinuoray iyot ra man diay imong tuyo' | Predicted: Not Profane | True Label: 1
# Sentence: 'abi nimo buang ko' | Predicted: Profane | True Label: 1
# Sentence: 'ayaw padaka ang akong atay' | Predicted: Not Profane | True Label: 1
# Sentence: 'ang amaw maglisod og sabot sa mga tugon' | Predicted: Not Profane | True Label: 1
# Sentence: 'bisan asa ko motanaw ang mga amaw lang ang akong nakita' | Predicted: Not Profane | True Label: 1
# Sentence: 'nanghapdos ang bisong ni mary sa unang panaghilawas nilang tom' | Predicted: Not Profane | True Label: 1
# Sentence: 'dili matuohan ang amaw sa pipila politiko' | Predicted: Not Profane | True Label: 1
# Sentence: 'duha ka gituohang tulo hangtud upat ka bulan nga baktin ang napalgan gihikot sa kahoy didto sa suba' | Predicted: Not Profane | True Label: 1
# Sentence: 'ayaw paghalahala og dala og hayop dinhi' | Predicted: Profane | True Label: 1
# Sentence: 'abi nimo buang ko' | Predicted: Profane | True Label: 1
# Sentence: 'ayaw padaka ang akong atay' | Predicted: Not Profane | True Label: 1
# Sentence: 'bisan asa ko motanaw ang mga amaw lang ang akong nakita' | Predicted: Not Profane | True Label: 1
# Sentence: 'nanghapdos ang bisong ni mary sa unang panaghilawas nilang tom' | Predicted: Not Profane | True Label: 1
# Sentence: 'dili matuohan ang amaw sa pipila politiko' | Predicted: Not Profane | True Label: 1
# Sentence: 'duha ka gituohang tulo hangtud upat ka bulan nga baktin ang napalgan gihikot sa kahoy didto sa suba' | Predicted: Not Profane | True Label: 1
# Sentence: 'ayaw paghalahala og dala og hayop dinhi' | Predicted: Profane | True Label: 1
# Sentence: 'sama ka sa usa ka buangbuang' | Predicted: Profane | True Label: 1
# Sentence: 'buang ang mga ideya niya' | Predicted: Profane | True Label: 1
# Sentence: 'ug si ada nanganak kang jabal nga mao ang amahan sa mga nagapuyo sa mga balongbalong ug may mga hayup' | Predicted: Profane | True Label: 1
# Sentence: 'ug siya nagbuhat ug maayo kang abram tungod kaniya ug siya may mga carnero ug mga vaca ug mga asno ug mga ulipon nga lalake ug mga binatonan nga babaye ug mga asno nga baye ug mga camello' | Predicted: Not Profane | True Label: 1
# Sentence: 'ug si sarai nga asawa ni abram wala maganak kaniya ug siya may usa ka binatonan nga babaye nga egiptohanon nga gihinganlan si agar' | Predicted: Not Profane | True Label: 1
# Sentence: 'busa miingon si sarai kang abram nakita mo na nga ako nahimo ni jehova nga apuli mangayo ako kanimo nga dumuol ka sa akong binatonan nga babaye tingali nga ako makabaton ug mga anak pinaagi kaniya' | Predicted: Profane | True Label: 1
# Sentence: 'Piniste nimo ang akong problema, salamat kaayo!' | Predicted: Not Profane | True Label: 1
# Sentence: 'Asa nimo piniste ang imong bag?' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ang maestra miingon nga dapat nato piniste ang mga kalapasan.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ngano man nga wala nimo piniste ang akong giingon?' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ang bata kay giingnan sa iyang ginikanan nga piniste ang iyang kalat.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Giunsa nimo pag-piniste ang imong trabaho sa dali nga panahon?' | Predicted: Not Profane | True Label: 1
# Sentence: 'Palihug piniste ang lamesa kay naay abot nga bisita.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ang tanang estudyante piniste ang ilang test papers.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Wala pa nimo piniste ang imong isyu sa imong amigo?' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ang mga trabahante kinahanglan piniste ang ilang tahas sa deadline.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Dapat nato piniste ang mga kahuyang sa atong balay.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Wala pa nimo piniste ang imong assignment?' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ang mga mananagat piniste ang ilang pukot sa pagkaayo.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Kinsa man ang nag-piniste sa among report gahapon?' | Predicted: Not Profane | True Label: 1
# Sentence: 'Nagpasalamat ang manager nga imo nang piniste ang mga problema sa opisina.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Palihug piniste ang mga plato human mangaon.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Gusto nako nga piniste ang tanang gubaon nga gamit sa kusina.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Maayo kaayo ka sa pag-piniste sa imong mga buluhaton.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ang mga mag-uuma piniste sa ilang yuta para andam sa tanom.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ngano wala pa nimo piniste ang imong mga kasaypanan?' | Predicted: Not Profane | True Label: 1
# Sentence: 'Dapat nato piniste ang tanang kahugaw diri sa atong palibot.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Palihug piniste ang akong libro kay kinahanglan nako.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Wala ka pa ba nag-piniste sa imong mga plano para ugma?' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ang among silingan nag-piniste sa iyang sakyanan ganiha.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ang among amahan miingon nga kinahanglan natong piniste ang tanan una kita mopauli.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Giunsa nimo pag-piniste ang imong utang sa dali nga panahon?' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ang tanang empleyado piniste sa ilang mga papel human ang miting.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Dili maayo nga magpabilin ang problema, kinahanglan nato kini piniste.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ang maestro piniste ang tanang mga hagit sa klase.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ang mga bata piniste sa ilang dula human ang klase.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Gusto nako nga piniste nimo ang imong trabaho para makarelax ka na.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Dili ka pa kauli hangtod nga imo nang piniste ang imong balay.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ang akong igsoon nag-piniste sa iyang proyekto kagabii.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Giingnan nako siya nga palihug piniste ang akong gisugo.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Human na ba nimo piniste ang mga papel nga imong gibutang sa lamesa?' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ang akong mama miingon nga kinahanglan piniste nato ang tanang hugaw.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ngano wala nimo piniste ang imong mga gipangsulti ganiha?' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ang among maestro nag-piniste sa tanang masulubon nga estudyante.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ang tigulang piniste ang mga tanom human ang ulan.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Gusto nako nga akong pamilya mahimong piniste sa ilang mga kasabutan.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ngano wala pa nimo piniste ang imong mga papeles alang sa aplikasyon?' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ang among barangay kapitan piniste sa tanang reklamo sa komunidad.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ang among team piniste ang problema nga among giatubang.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Si Juan wala pa mag-piniste sa iyang mga plano para sa negosyo.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ang akong iro piniste ang iyang mga dulaan diha sa silong.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ang akong lola piniste ang tanang mga panapton para limpyo ug humot.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ang maestra piniste ang tanang palpak nga sagot sa eksamin.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Dapat nato piniste ang atong mga kalapasan aron kita magmalinawon.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ako nang piniste ang tanang kinahanglan nga dokumento.' | Predicted: Not Profane | True Label: 1
# Sentence: 'Ang among opisina piniste na ang tanan sa wala pa ang inspeksyon.' | Predicted: Not Profane | True Label: 1
# Sentence: 'unsang kadugayon kamo nga mga walaypagtagad nga higugmaon ninyo ang pagkawalaypagtagad ug ang mga mayubiton mahimuot kanila sa pagyubit ug ang mga buang sa pagdumot sa kinaadman' | Predicted: Profane | True Label: 1
# Sentence: 'kay ang pagkasukihan sa mga tawong walaypagtagad mopatay kanila ug ang mapasagarong pagpatuyang sa mga buang molaglag kanila' | Predicted: Profane | True Label: 1
# Sentence: 'ang manggialamon makapanunod sa himaya apan ang kaulaw maoy makapauswag sa mga buang' | Predicted: Profane | True Label: 1
# Sentence: 'siya misunod kaniya sa walay langan ingon sa usa ka vaca nga nagapadulong ngadto sa ihawan kun maingon sa usa nga anaa sa mga talikala aron sa pagtulid sa mga buang' | Predicted: Profane | True Label: 1
# Sentence: 'hangtud nga ang usa ka udyong molagbas sa iyang atay ingon sa usa ka langgam nga nagdali ngadto sa litag ug wala manghibalo nga kana alang sa iyang kinabuhi' | Predicted: Not Profane | True Label: 1
# Sentence: 'oh kamo nga mga walaypagtagad sabta ang pagpilisamaayo ug kamong mga buang pagmasinabtanon kamo sa inyong kasingkasing' | Predicted: Profane | True Label: 1
# Sentence: 'ang buangbuang nga babaye sabaan man siya walaypagtagad ug walay hibangkaagan' | Predicted: Profane | True Label: 1
# Sentence: 'ang mga proverbio ni salomon ang usa ka anak nga manggialamon maoy kalipay sa iyang amahan apan ang usa ka anak nga buangbuang maoy kaguol sa iyang inahan' | Predicted: Profane | True Label: 1
# Sentence: 'ang manggialamon sa kasingkasing magadawat ug mga sugo apan ang usa ka buangbuang nga witwitan mahulog sa kagulanan' | Predicted: Profane | True Label: 1
# Sentence: 'kadtong nagapangilo sa mata nagahatag ug kasubo apan ang usa ka buangbuang nga witwitan mahulog sa kagulanan' | Predicted: Profane | True Label: 1
# Sentence: 'ang mga tawong manggialamon nagatigum ug kahibalo apan ang baba sa buangbuang mao ang usa ka pagkalaglag karon' | Predicted: Profane | True Label: 1
# Sentence: 'kadtong nagatago sa pagdumot adunay bakakon nga mga ngabil ug kadtong nagapamulong us usa ka butangbutang maoy usa ka buang' | Predicted: Profane | True Label: 1
# Sentence: 'ang mga ngabil sa matarung magapakaon ug daghan apan ang buangbuang mamatay tungod sa pagkakulang ug salabutan' | Predicted: Profane | True Label: 1
# Sentence: 'maoy usa ka lingawlingaw sa usa ka buang ang pagbuhat ug kadautan ug maingon niini ang kaalam alang sa usa ka tawo nga masinabuton' | Predicted: Profane | True Label: 1
# Sentence: 'kadtong nagasamok sa iyang kaugalingong balay magapanunod sa hangin ug ang buang mahimong ulipon sa manggialamon ug kasingkasing' | Predicted: Profane | True Label: 1
# Sentence: 'ang dalan sa usa ka buang matarung man sa iyang kaugalingong mga mata apan kadtong manggialamon nagapamati ug tambag' | Predicted: Profane | True Label: 1
# Sentence: 'ang kasuko sa usa ka buang mahibaloan dayon sa dayag apan ang usa ka mabinantayong tawo nagabaton ug kaulaw' | Predicted: Profane | True Label: 1
# Sentence: 'ang usa ka tawong buotan nagabaton ug kahibalo apan ang kasingkasing sa mga buang nagabutyag sa kabuangan' | Predicted: Profane | True Label: 1
# Sentence: 'ang tagsatagsa ka buotan nga tawo magabuhat uban sa kahibalo apan ang buang magapagarbo sa iyang binuang' | Predicted: Profane | True Label: 1
# Sentence: 'ang tinguha nga natuman maoy katamis sa kalag apan maoy usa ka dulumtanan sa mga buang ang pagbiya gikan sa dautan' | Predicted: Profane | True Label: 1
# Sentence: 'lakat uban sa tawong manggialamon ug ikaw mahimong manggialamon apan ang kauban sa mga buang magaantus tungod niana' | Predicted: Profane | True Label: 1
# Sentence: 'ang mga buang magatiawtiaw lamang sa haladtungodsasala apan sa taliwala sa mga matarung adunay maayong kabubuton' | Predicted: Profane | True Label: 1
# Sentence: 'ang usa ka tawong manggialamon mahadlok ug magapahilayo gikan sa dautan apan ang buang mapangahason sa iyang kaugalingon nga may pagdaut ug siya masaligon' | Predicted: Profane | True Label: 1
# Sentence: 'ang purongpurong sa mga manggialamon mao ang ilang mga bahandi apan ang binuang sa mga buang mao lamang ang kabuangan' | Predicted: Profane | True Label: 1
# Sentence: 'ang kaalam magapuyo diha sa kasingkasing niadtong may salabutan apan kadtong anaa sa sulod sa mga buang mapadayag sa iyang kaugalingon' | Predicted: Profane | True Label: 1
# Sentence: 'ang dila sa manggialamon sa matulid nagapamulong ug kahibalo apan ang baba sa mga buang nagabubo sa kabuangan' | Predicted: Profane | True Label: 1
# Sentence: 'ang usa ka buang magatamay sa pagsaway sa iyang amahan apan kadtong nagatagad sa pagbadlong nagapakita sa pagkabuotan' | Predicted: Profane | True Label: 1
# Sentence: 'ang kasingkasing niadtong may salabutan nagapangita ug kahibalo apan ang baba sa mga buang nagakaon sa mga binuang' | Predicted: Profane | True Label: 1
# Sentence: 'ang salabutan maoy usa ka atabay nga tuburan sa kinabuhi niadtong nagabaton niini apan ang pagsaway sa mga buang mao ang ilong binuang' | Predicted: Profane | True Label: 1
# Sentence: 'ang pakigpulong nga labing maayo dili mahatungod sa usa ka buang labing dili angay ang bakakon nga mga ngabil sa usa ka principe' | Predicted: Profane | True Label: 1
# Sentence: 'ang usa ka pagbadlong motidlum sa halalum gayud nganha sa usa nga may salabutan kay sa usa ka gatus nga mga labud nganha sa usa ka buang' | Predicted: Profane | True Label: 1
# Sentence: 'ipasugat sa usa ka oso nga nawadan sa iyang mga anak ang usa ka tawo kay sa usa ka buang diha sa iyang binuang' | Predicted: Profane | True Label: 1
# Sentence: 'busa aduna bay bili diha sa kamot sa usa ka buang aron sa pagpalit sa kaalam sanglit siya wala may salabutan' | Predicted: Profane | True Label: 1
# Sentence: 'kadtong nanganak ug usa ka buang nakaangkon niini sa iyang kasubanan ug ang amahan sa usa ka buang walay kalipay' | Predicted: Profane | True Label: 1
# Sentence: 'ang kaalam anaa sa atubangan sa nawong niadtong may salabutan apan ang mga mata sa usa ka buang anaa sa mga kinatumyan sa yuta' | Predicted: Profane | True Label: 1
# Sentence: 'bisan ang usa ka buang kong siya magahilum pagaisipon nga manggialamon kong siya magatakom sa iyang mga ngabil siya pagatamdon nga ingon sa buotan' | Predicted: Profane | True Label: 1
# Sentence: 'ang usa ka buang walay kalipay diha sa pagsabut apan mao lamang nga ang iyang kasingkasing magabutyag sa iyang kaugalingon' | Predicted: Profane | True Label: 1
# Sentence: 'ang mga ngabil sa buang magadala kaniya ngadto sa pagkabingkil ug ang iyang baba magapanawag sa mga labud' | Predicted: Profane | True Label: 1
# Sentence: 'ang baba sa usa ka buang maoy iyang kalaglagan ug ang iyang mga ngabil maoy litag sa iyang kalag' | Predicted: Profane | True Label: 1
# Sentence: 'maayo pa ang kabus nga magalakat diha sa iyang pagkahingpitsakasingkasing kay kaniya nga sukwahi sa iyang mga ngabil ug maoy usa ka buang' | Predicted: Profane | True Label: 1
#
# Evaluation Metrics:
# True Positives (TP): 181
# True Negatives (TN): 602
# False Positives (FP): 10
# False Negatives (FN): 206
# Accuracy: 0.7838
# Precision: 0.9476
# Recall: 0.4677
# F1 Score: 0.6263

# %%
import torch
import pandas as pd

# Initialize counters for metrics calculation
tp = 0  # True Positives
tn = 0  # True Negatives
fp = 0  # False Positives
fn = 0  # False Negatives

# Determine the device for the model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Load CSV file
file_path = '/content/drive/MyDrive/BERT/Testing_Data - Bikol.csv'  # Replace with your CSV file path
data = pd.read_csv(file_path)

# Loop through the rows of the DataFrame
for index, row in data.iterrows():
    sentence = row['sentence']
    true_label = row['profane']

    # Tokenize the input sentence and move to the appropriate device
    inputs = tokenizer(sentence, return_tensors="pt")
    inputs = {key: val.to(device) for key, val in inputs.items()}  # Move inputs to the same device as the model

    # Perform inference
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits

    # Get the predicted class (0: Not Profane, 1: Profane)
    predicted_class = torch.argmax(logits, dim=-1).item()

    # Update counters
    if predicted_class == 1 and true_label == 1:
        tp += 1  # True Positive
    elif predicted_class == 0 and true_label == 0:
        tn += 1  # True Negative
    elif predicted_class == 1 and true_label == 0:
        fp += 1  # False Positive
    elif predicted_class == 0 and true_label == 1:
        fn += 1  # False Negative

    # Print the result
    if predicted_class == 1:
        print(f"Sentence: '{sentence}' | Predicted: Profane | True Label: {true_label}")
    else:
        print(f"Sentence: '{sentence}' | Predicted: Not Profane | True Label: {true_label}")

# Calculate Precision, Recall, F1-Score, and Accuracy
precision = tp / (tp + fp) if (tp + fp) > 0 else 0
recall = tp / (tp + fn) if (tp + fn) > 0 else 0
f1_score = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn) if (tp + tn + fp + fn) > 0 else 0

# Display evaluation metrics
print("\nEvaluation Metrics:")
print(f"True Positives (TP): {tp}")
print(f"True Negatives (TN): {tn}")
print(f"False Positives (FP): {fp}")
print(f"False Negatives (FN): {fn}")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1_score:.4f}")
# Out:
# Sentence: 'sa komun na arapodan orog na sa mga eskwelahan natotomoyan ining bayan magiliw' | Predicted: Not Profane | True Label: 0
# Sentence: 'siya nagin aktibong kaapil kan partido liberal asin ngane nagin tesorero asin adviser kan partidong ini' | Predicted: Not Profane | True Label: 0
# Sentence: 'pigkaag man sa posisyon sa department of earth and planetary science asin sa department of environmental science policy and management' | Predicted: Not Profane | True Label: 0
# Sentence: 'an saiyang pamomoon sa kambodya bantog sa maringis na pagtrato sa sadiri niyang kahimanwa mala ta sinasabing napagadan niya an haros kan populasyon sa kun anoanong rason' | Predicted: Not Profane | True Label: 0
# Sentence: 'an amerikanang parakanta na si lady gaga nagpaluwas nin tolong video albums asin nakaluwas sa trentang mga music video' | Predicted: Not Profane | True Label: 0
# Sentence: 'pero bilang tropikal na depresyon sa katapustapusi kan hulyo nagkaigwa nin tropikal na depresyon sa solnopan na pasipiko sa sirangan kan islas luzon kan pilipinas' | Predicted: Not Profane | True Label: 0
# Sentence: 'taon kan madestino sa buhi si fray francisco de san juan evangelista ofm sya an kagsurat kan una explicacion de la doctrina cristiana' | Predicted: Not Profane | True Label: 0
# Sentence: 'an vayu purana asin an brahmanda purana nagsasbi na an pitong makapangyarihan na mha hade nagpadalagan sa kapitolyo kan kosala' | Predicted: Not Profane | True Label: 0
# Sentence: 'ini importanteng sangkap sa mga gisong arabo asin indyano' | Predicted: Not Profane | True Label: 0
# Sentence: 'nabantog sa tribu an gibo ni baltog' | Predicted: Not Profane | True Label: 0
# Sentence: 'an papel ni blair komo primer ministro hayag na gayo sa pulitikang panluwas asin sa seguridad kun saen sa norteng irlandya siya nagpirma kan sa inapod na biyernes santong pagoroyon' | Predicted: Not Profane | True Label: 0
# Sentence: 'an miskonsepsyon iyo dara kan amerikanong anthropolohista na si h otley beyer na iyo naghimo sa mga filipino bilang mga malay talaga na nagluwas nin panorte gikan sa malaysia asin indonesia sa ngunyan' | Predicted: Not Profane | True Label: 0
# Sentence: 'kan nataas siya sa katongdan ta ginibo na siyang subkumander kan telecoms service kan ikaduwang rehiyon' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa laog nin duwang aldaw siya pigpasakitan pa sa kumbento kan simbahan nin san francisco dangan ikinonkon sa karsel kun saen siya naotsan ta dai natagalan an makuring kulog sa hawak na saiyang sinapo sa pagparakadog saiya' | Predicted: Not Profane | True Label: 0
# Sentence: 'an tinola parehas sa binakol asin ginataang manok nagkakaiba lang sa paggamit nin niyog asin gata' | Predicted: Not Profane | True Label: 0
# Sentence: 'si rizal bakong rebolusyonaryo na maghorot nin katalingkasan' | Predicted: Not Profane | True Label: 0
# Sentence: 'magkapirang pananaw sa mga kristiyano an manongod sa oras nin pagbalik ni hesukristo asin kaiba na diyan an punto kun ini mangyayari sararoan sana o magkaduwang beses an manongod sa pagtiripon' | Predicted: Not Profane | True Label: 0
# Sentence: 'an duwang pelikulang ini kairiba pa an nagsurunod nagsemento kan popularidad niya bilang aktor asin bilang tagahakot pirak sa takilya' | Predicted: Not Profane | True Label: 0
# Sentence: 'na sa tahaw si sugitan na ogma' | Predicted: Not Profane | True Label: 0
# Sentence: 'itinutulod man kan relihiyong hainismo an labi na asetismo pagaayuno yoga asin iba pang awsteridad para sa obhetong pagninilaynilay o meditasyon' | Predicted: Not Profane | True Label: 0
# Sentence: 'an maski anong punto sa selestyal na koordinatong sistema iyo yaon sa saro sa mga modernong konstelasyon' | Predicted: Not Profane | True Label: 0
# Sentence: 'si tanaka hisashige oktobre nobyembre sarong hapon na rangaku iskolar inhenyero asin imbentor durante kan periodo pagoltan kan bakumatsu asin kaamayan kan meiji sa hapon' | Predicted: Not Profane | True Label: 0
# Sentence: 'si gebre sarong biktima nin genital mutilation sa kababaihan sa edad na ipinagbawal ki gebre kan saiyang ama an sarong pormal na edukasyon alagad nagluwas siya sa saiyang harong tanganing magatendir sa sarong paadalan nin misyonero' | Predicted: Not Profane | True Label: 0
# Sentence: 'an mga monomero kan nucleotide iyo mahihiling sa mga selulang nukleyus' | Predicted: Not Profane | True Label: 0
# Sentence: 'igwang natatadang na aldaw sagkod kan katapusan nin taon' | Predicted: Not Profane | True Label: 0
# Sentence: 'si johansson ugos sa saiyang lolahun sa ina si dorothy sloan sarong bookkeeper asin maestra pirmi sindang magkaibahan asin kinokonsiderar siya ni johansson bilang sarong kaugos na amiga' | Predicted: Not Profane | True Label: 0
# Sentence: 'maski na ngani kaining posisyon kan lds na simbahan an terminong mormon iyo an lawig na pinaggagamit kan mga journalists asin bakong journalist sa pagpapanungod sa mga tagasunod kan pundamentalismong mormon' | Predicted: Not Profane | True Label: 0
# Sentence: 'kun nakikipag olay ako manongod sa pagduman sa mga tinampo pinag oolayan ko an dapit sa paggibo nin iribang kosog' | Predicted: Not Profane | True Label: 0
# Sentence: 'huli sa reglamentos kan miss universe na nagsasabing ibinabawa sa mga kandidata an kasal na bago an pinal na kompetisyon pinwersang maghilig sa pwesto si santamaria asin hinirang na bagong miss colombia si zuluaga' | Predicted: Not Profane | True Label: 0
# Sentence: 'an pigiimponsor an pitong pambungog na mga eskwelahan sa madagaskar kan mga evangelical lutheran' | Predicted: Not Profane | True Label: 0
# Sentence: 'an bise presidente kan estados unidos iyo na nagkakapot kan sarong panpublikong opisina na pigbilog kan kostitusyon kan estados unidos' | Predicted: Not Profane | True Label: 0
# Sentence: 'huna kan kastila an nadangog niyang nasubo iyo si pangaran' | Predicted: Not Profane | True Label: 0
# Sentence: 'bago ini apudon na dinastiyang qin an mga ying an namumuno sa qin nacion' | Predicted: Not Profane | True Label: 0
# Sentence: 'siya man popular man sa enterong kinaban dawa nagadan na' | Predicted: Not Profane | True Label: 0
# Sentence: 'dangan ta bawal na saiya magkapot kan pwesto pagkaalkalde siya nagdalagan bilang kongresista asin guminana dara niya an enot na distrito kan siyudad nin davao' | Predicted: Not Profane | True Label: 0
# Sentence: 'an gabos na danyos hale sa tipono nakaabot sa trilyon esu milyones' | Predicted: Not Profane | True Label: 0
# Sentence: 'nagaba ini kan bagyo kan asin natomtom sa kalayo kan' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa tabang kan saiyang amiga asin kaklase na si mildred orrick natapos ni mccardell an saiyang koleksyon na nakaratay sa ospital' | Predicted: Not Profane | True Label: 0
# Sentence: 'siya dating katuwang na hokom kan korte suprema kan filipinas' | Predicted: Not Profane | True Label: 0
# Sentence: 'kadakol an naggagradwar sa unibersidad na nanginot sa mga eksaminasyon nasyonal rehiyonal asin probisyal na lebel' | Predicted: Not Profane | True Label: 0
# Sentence: 'pero an relasyon pulitikal asin ekonomiko kan hapon asin amnayan korea dai guminantad' | Predicted: Not Profane | True Label: 0
# Sentence: 'poon sagkud nagpakasal sya sa stockhomer negosyanteng si a agrell' | Predicted: Not Profane | True Label: 0
# Sentence: 'an pransyo iyo nadiskobre kaidtong nin kimikong pransesa na si marguerite perey' | Predicted: Not Profane | True Label: 0
# Sentence: 'sar sa pinakabistadong mga piyesa kan literaturang bietnames iyo an the tale of kiu na piggibo sa ch nm' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa arabo an kahulogan kan taharrush arabong na pagngangalwag arabong na pambabastos ingles collective harassment' | Predicted: Not Profane | True Label: 0
# Sentence: 'asin man si iu napili bilang embahadora para sa expo na pigganap sa yeosu' | Predicted: Not Profane | True Label: 0
# Sentence: 'an prutas inapod na elephant apple sa ingles may diametro na lima asin anom na sentimetro' | Predicted: Not Profane | True Label: 0
# Sentence: 'an rekomendasyon na sana iyo na magkaigwa nin otrolaban an duwang boksyador' | Predicted: Not Profane | True Label: 0
# Sentence: 'an saiyang rawitdawit na kauntokan giraray napublikar sa librong sagurong na kontemporanyong rawitdawit sa manlainlain na tataramon bikol dlsu' | Predicted: Not Profane | True Label: 0
# Sentence: 'an hinduismo iyo nababanga sa numero nin mga mayor sa ngunyan an mga bisto iyo an vaishnavismo shaivismo smartismo asin shaktismo' | Predicted: Not Profane | True Label: 0
# Sentence: 'nalabot sa daga na tiponan kan mga tayang dyolin' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa ibaibang kultura an mga pangaran kan mga arkanghel ginagamit parati komo kangaranan enot na pangaran nin mga lalake' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa huring oras kan enero an gabos na senyal sa visayas kinanselar na nangangahulogan nin nagdidikit na doros' | Predicted: Not Profane | True Label: 0
# Sentence: 'an reaktibidad kan sarong minaganang grupo iyo pwedeng mamodipika kan iba pang mga haraning minaganang grupo' | Predicted: Not Profane | True Label: 0
# Sentence: 'an iba pang mga framework sa karapatan pantawo arog baga kan convention on the rights of the child nanunugod sa mga isyung pankapalibutan mantang nagtatakod sa pokus kan framework na sa kasong ini sa mga karapatan kan kaakian' | Predicted: Not Profane | True Label: 0
# Sentence: 'catalina an busay nin bantakay' | Predicted: Not Profane | True Label: 0
# Sentence: 'nawalat niya an saiyang agom an nagligad na miss philippines asin queen kan philippine carnival engracia laconico sagkod apat na aki si antonio pacita josefina asin lourdes' | Predicted: Not Profane | True Label: 0
# Sentence: 'dangan sya nadestino sunodsunod bilang ministro sa mga banwaan nin indan bula quipayo daet naga oas asin sa minalabag minalabac' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa sinabing okasyon an kasararoan pinagpilang asin tinawan onra an tolong mga beterano sa gera sinda maj' | Predicted: Not Profane | True Label: 0
# Sentence: 'kadtong ika nin hulyo naghost siya nin sarong luncheon bilang karangalan para sa koronasyon kan saiyang mga magurang sa matakieua villa na pigatendiran kan an maharlikang pamilya kan tonga nobya kan tongano' | Predicted: Not Profane | True Label: 0
# Sentence: 'sya nagin prangka sa saiyang mga kahagadan para sa sunod na vunivallu of bau na minimidbid bilang pinakahalangkaw na titulo ni fiji na elehido kan bilog na baui kaba imbes na nombrahan nin pirang mga gurang na myembros' | Predicted: Not Profane | True Label: 0
# Sentence: 'enot na nagkahilingan sinda vallejo asin bachelet sa sarong campaign event kadtong ika nin hunyo' | Predicted: Not Profane | True Label: 0
# Sentence: 'namundag sa sursubangan kan estados unidos alagad saiyang binutasan an nasyunalidad niyang pagkaamerikano kan nagin siyang sweso sa nasyunalidad' | Predicted: Not Profane | True Label: 0
# Sentence: 'an mga prediksion sa naturalesa para sa presenteng trahedya nin klima naghula na an pag init sa bilog na globo posibleng malabihan an doot na si celsio na posibleng marhay na degreso pag abot nin' | Predicted: Not Profane | True Label: 0
# Sentence: 'pagdedebosyon na natao sa lambang moslem nin displina makusog na pagtubod ki allah asin pakisumaro sa mga tingating' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa pelikula nagin parte siya kan mga primerong tauhan sa st ko si rd' | Predicted: Not Profane | True Label: 0
# Sentence: 'dibursyado an mga magurang niya' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa mga pwera sa filipinas darakulang lubang an ginagamit sa pagdais kan paroy na magin bagas asin duwa katawo nagriribayribay sa pagbukbok kan paroy gamit tigsarong hlo' | Predicted: Not Profane | True Label: 0
# Sentence: 'an jtwc nagtao nin mga advisories manungod ki fergus sa sumunod na amay na pagkaaga asin ini ipigdesignar na tropikal na buhawi p mantang ini harani sa renell island' | Predicted: Not Profane | True Label: 0
# Sentence: 'an angers sarong ciudad na nammogtk sa sursubangan na kanto nin estado nin anjou' | Predicted: Not Profane | True Label: 0
# Sentence: 'an piling species na n tabacum iyo an inaataman asin kinukultibar sa bilog na kinaban sa pagkua igdi kan dahon sa komersyal na pagprodyusir nin sigarilyo asin iba pang produkto sa tabako' | Predicted: Not Profane | True Label: 0
# Sentence: 'an sabi pa kan new york times na an pagpartisipar kan mga babayi sa wikipedia baad kalinya kan public thoughtleadership forums' | Predicted: Not Profane | True Label: 0
# Sentence: 'inuusar man ining pambahog sa mga orig o baka' | Predicted: Not Profane | True Label: 0
# Sentence: 'siya an ina ni liezl martinez' | Predicted: Not Profane | True Label: 0
# Sentence: 'an pagaalsang ini kan mga gwardya sibil inutasan na an buhay kan gobyernong kastila sa probinsya asin sa masurunod na aldaw pati idtong sa ibang probinsya sa kabikolan' | Predicted: Not Profane | True Label: 0
# Sentence: 'ilinubong siya sa national cemtery kan santa fe new mexico' | Predicted: Not Profane | True Label: 0
# Sentence: 'pigkokonsiderar na mga pamanang kultural an kabayan mummy sa irarom kan presidential decree no' | Predicted: Not Profane | True Label: 0
# Sentence: 'garcia sa pagbalik kani kuta sa pwesto komo presidente' | Predicted: Not Profane | True Label: 0
# Sentence: 'siya duwangbeses nagin ibf asin ibo light welterweight na kampyon' | Predicted: Not Profane | True Label: 0
# Sentence: 'sinabat man kuta kan pwersa na lukban duman sa calabanga alagad huli sa superior na armas kan mga amerikano napiritan sindang magaratras' | Predicted: Not Profane | True Label: 0
# Sentence: 'pero ganoon talaga yata ang epekto niya parang mompo na hinaluan ng tanduay tagay lang nang tagay basa lang nang basa hanggang maubusan ng hininga at pahina' | Predicted: Not Profane | True Label: 0
# Sentence: 'ini dinadayo na gayo kan mga turista asin masabi na dai kumpleto an pagbisita sa pasig kun an sarong turista o bisita dai mapagabay igdi' | Predicted: Not Profane | True Label: 0
# Sentence: 'ini tinuturon binabaduya saka pinapatos sa arinang may hamis asin pinipritos dangan tinutuhog' | Predicted: Not Profane | True Label: 0
# Sentence: 'ilinubong siya sa sacred heart novitiate cemetery sa novaliches quezon city kan nobyembre sa edad na' | Predicted: Not Profane | True Label: 0
# Sentence: 'kaidtong pigtantya na an ordinaryong koreano na mayedad mas matanda sa iyo nakaubos nin na bote nin soju sa taong ito' | Predicted: Not Profane | True Label: 0
# Sentence: 'an dwgbfm okfm legazpi sarong bagong togdas na istasyon nin radyo kan pbn broadcasting network asin ditse lala broadcasting company inc' | Predicted: Not Profane | True Label: 0
# Sentence: 'siya an nagsararo kan pwersa nin mga kurdish asin mga shia ngani burunyog na bokbokon na husto an isis mala ta siya an nagdidirihe kan mga operasyon kan duwang pwersa' | Predicted: Not Profane | True Label: 0
# Sentence: 'naglingkod man sya bilang chairman kan career executive service board sarong ahensya kan gobyerno na namamahala sa pinakahalangkaw na management personnel kan gobyerno kan pilipinas' | Predicted: Not Profane | True Label: 0
# Sentence: 'pwersa sa pagigin historyador si constantino kabali man sa serbisyo sa mga dayuhan nagtatrabaho para sa philippine mission to the united nations asin department of foreign affairs' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa mga lalaki garo sana ini bakong krimen kundi arabrakan' | Predicted: Not Profane | True Label: 0
# Sentence: 'kan nakaagi ni brown kabtang sia kan blights outs and antenna' | Predicted: Not Profane | True Label: 0
# Sentence: 'kaya an santuario ni ina na gibo sa gogon mga sarong kilometro an rayo sa katedral na harani sa may tabuko' | Predicted: Not Profane | True Label: 0
# Sentence: 'nadiskubre na igwa nin hilang na aids si kaliias kan' | Predicted: Not Profane | True Label: 0
# Sentence: 'igwang katawong nageerok digdi alaga nagaabot an tawo sa teritoryo huli sa mga tawong nagaadal naghahanapbuhay asbp' | Predicted: Not Profane | True Label: 0
# Sentence: 'gascon pigdonar na logod an estruktura sa philippine tourism authority ngonyan inaapod nang tourism infrastructure and enterprise zone authority' | Predicted: Not Profane | True Label: 0
# Sentence: 'an mabilison na nakapagguno nin mga parasunod na pinaghihiling si smith bilang sarong propeta' | Predicted: Not Profane | True Label: 0
# Sentence: 'an saindang banda na pinamayohan ni lombardo nabantog na gayo sa kinaban' | Predicted: Not Profane | True Label: 0
# Sentence: 'nakamit niya man an mga honorary degree sa doctor of science haleng brigham young university kan doctor of medical science haleng utah state university kan asin doctor of humane letters sa snow college kan' | Predicted: Not Profane | True Label: 0
# Sentence: 'mahihiling sa probinsya kan sur na sulawesi an pirang mga tataramon sa selibiko hal' | Predicted: Not Profane | True Label: 0
# Sentence: 'pakaparatos na matilaba pero bilogon an hitsura dinudupil an duwang pinatos asin binubugkos sa tig aporo' | Predicted: Not Profane | True Label: 0
# Sentence: 'igwa igdi nin mga tulay na may total na laba na kilometro' | Predicted: Not Profane | True Label: 0
# Sentence: 'siya an binibistong lider man ngaya kan grupo' | Predicted: Not Profane | True Label: 0
# Sentence: 'an pagaadal kan virus iyo bistado bilang birolohiya sarong sangay kan mikrobiyolohiya' | Predicted: Not Profane | True Label: 0
# Sentence: 'marso kan an alyansa kan mga artista para sa pagmukn kan sarong ministro kan kultura o alliance of artists for the creation of a ministry of culture aacmc naghaman nin sarong propwesto para sa pagmukn nin sarong ministro kan kultura' | Predicted: Not Profane | True Label: 0
# Sentence: 'saro ining gamit na nakukua sa mga lumang papel kan sarong munisipyo' | Predicted: Not Profane | True Label: 0
# Sentence: 'haonon na saka isirbi' | Predicted: Not Profane | True Label: 0
# Sentence: 'an saiyang tula na pabakal nakaayon sa antolohiyang sagurong na kontemporanyong rawitdawit sa manlainlain na tataramon bikol' | Predicted: Not Profane | True Label: 0
# Sentence: 'si nidal al achkar namundag kan sarong lebanong aktres asin direktor sa teatro na ikinukonsiderar bilang the grande dame of lebanese theater' | Predicted: Not Profane | True Label: 0
# Sentence: 'an estasyon nin katipunan o himpilang katipunan sarong estasyon sa linyang asul kan sistemang magian na riles pambalyo kan manila mrt' | Predicted: Not Profane | True Label: 0
# Sentence: 'para sa presyo kan sar pan tiket pwede an mga bisita magsakay nin sar pan linyada nin mga elevator gikan sa ikaduwang salg kan pangenot na obserbatoryo tanganing maabot an pangwakas na pagoobserba na dekoan espesyal na observatoryo' | Predicted: Not Profane | True Label: 0
# Sentence: 'napasairarom man saiya an restorasyon kan herbarium na iyo labing nagaba durante kan giyera' | Predicted: Not Profane | True Label: 0
# Sentence: 'kaya lang gikan sa pananaw kan trinitariyanismo trinitarianism an mormonismo signipikanteng minaharayo gikan sa kristiyanidad' | Predicted: Not Profane | True Label: 0
# Sentence: 'an iskandalo totoo pwede tunay na basado sa katotohanan o produkto mansana nin mga pagduhagi o paglibak o may pagkatotoo pero napatos sa dagdag na mga kaputikan' | Predicted: Not Profane | True Label: 0
# Sentence: 'ginana kaini kan an winifred holtby memorial prize' | Predicted: Not Profane | True Label: 0
# Sentence: 'si heinrich beheim nagadan sarong aleman arkitekto asin kantero na taganuremberg' | Predicted: Not Profane | True Label: 0
# Sentence: 'an mga natadang mga drowing nagrerepresentar nin mga indibidwal mga lalake babae na padis mga habitanteng tagabuhis kan tsina na nakasulot nin pigbibistuhan na gayong gubing an iba drinowing bilang mga kawad' | Predicted: Not Profane | True Label: 0
# Sentence: 'an iba pang diskusyon iyo manungod sa pagkaag asin kategorisasyon nin mga ispesipikong elemento an futurong ekstensyon asin limitasyon kan tableta sagkod kun igwa baya nin optimong porma kan tableta' | Predicted: Not Profane | True Label: 0
# Sentence: 'an bako gayong magayon na pribadong buhay ni monroe nagtao saiya nin dakulang atensyon' | Predicted: Not Profane | True Label: 0
# Sentence: 'sin sa mga syudad sa angeles' | Predicted: Not Profane | True Label: 0
# Sentence: 'naelehir siyang kongresista para sa palawan nin duwang periodo poon asin nagin minority leader sa laog kan limang taon' | Predicted: Not Profane | True Label: 0
# Sentence: 'nagtapos siya sa kurso sa pagsurat kan thesis niyang study on plywood consumption in final consumption in surakarta municipality' | Predicted: Not Profane | True Label: 0
# Sentence: 'nagbababa man sa estasyong katipunan an mga taong paduman sa unibersidad kan filipinas sa diliman na medyo harayorayo man gikan sa estasyon' | Predicted: Not Profane | True Label: 0
# Sentence: 'ginibo na elise doganieri asin bertram van munster an pasali' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa amay kan abril si joseph smith asin oliver cowdery nagpatong nin mga kamot ki bro' | Predicted: Not Profane | True Label: 0
# Sentence: 'an saiyang agom na si osman pasha jaff sarong pasha asin namahala sia sa saiyang lugar kan mayo an saiyang agom' | Predicted: Not Profane | True Label: 0
# Sentence: 'dakol na pinagkapararehas sa lado nin balanghayan an diyalektong shikoku sa diyalektong chgoku' | Predicted: Not Profane | True Label: 0
# Sentence: 'an saiying notas hale sa irarom nin daga pigapod ni walter kauffmann na pinakan makusog na pagbukas kan existencialismo' | Predicted: Not Profane | True Label: 0
# Sentence: 'an pulot kaini sobrang naopot pag nadutaan asin haros mapakit an kublit kun pirit tinatangkas sa saiyang pagkapulot' | Predicted: Not Profane | True Label: 0
# Sentence: 'kailan pa man an saiyang album na revolution an pinakahuring numero uno na album hanggan' | Predicted: Not Profane | True Label: 0
# Sentence: 'an mayor na industriya sa kalibo iyo an agrikultura' | Predicted: Not Profane | True Label: 0
# Sentence: 'siya tigtawan kan posthumous nin jamaican order of merit kan' | Predicted: Not Profane | True Label: 0
# Sentence: 'an gobyerno nagtagama nin kahiwasan na km na basta dai pwede paglaogon sa pagproteher sa kapalibotan' | Predicted: Not Profane | True Label: 0
# Sentence: 'an wolpramyo o tungsten na bistado man bilang wolfram iyo sarong elementong kimikal na may simbolo na w asin atomikong bilang na an taramong tungsten iyo gikan sa tataramong swedish na tung sten na direktang mapapalis na magabat na gapo' | Predicted: Not Profane | True Label: 0
# Sentence: 'tinabngan man siy kan sayang tugang na si bernardo na iy an nagorganisar kan banda de libog' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa mga urap pwede ining makatalisa sa paagi nin mga protinang nagnunukleya nin tubig na nahimo nin mga atmosperikong mikrobyo na iyo may kakayahan na magdukot nin mga gas o likidong tubig na molekula' | Predicted: Not Profane | True Label: 0
# Sentence: 'an tunong ka ini ay magiging katinig na l pag pigdagdagan nin virama an irarom' | Predicted: Not Profane | True Label: 0
# Sentence: 'maitom na kayumanggi an saiyang palnit asin may sulot siyang pampayo na may ladawan kan sto' | Predicted: Not Profane | True Label: 0
# Sentence: 'kan amay nin ikang siglo an abbottabad nagin sarong kampo militar asin sanatorium asin nagsirberng kwartel kan brigada kan ikang dibisyon kan northern army corps' | Predicted: Not Profane | True Label: 0
# Sentence: 'tinutubudan na si sidapa igwa nin halangkawon na kahoy na dian sinosokol nia an buhay kan gabos na bagong mamundag asin ibinubugtak an tanda sa kahoy' | Predicted: Not Profane | True Label: 0
# Sentence: 'an jolo nagin sentro kan gobyerno kan sultanato nin sulu' | Predicted: Not Profane | True Label: 0
# Sentence: 'an the lost world igwang mga tradisyonal na atraksyon na yaon sa haros universal studios sa buong mundo' | Predicted: Not Profane | True Label: 0
# Sentence: 'matapos an sarong halipot na pagaadal sa sarong boarding school sa islington ipinadara kadtong si isabella sa eskwelahaan sa heidelberg alemanya na inibahan kan saiyang stepister na si jane dorling' | Predicted: Not Profane | True Label: 0
# Sentence: 'the prospects of industrial civilization katuwang si dora russell' | Predicted: Not Profane | True Label: 0
# Sentence: 'nababanga an imelda sa barangay' | Predicted: Not Profane | True Label: 0
# Sentence: 'buka an kumpetisyon sa gabos nin mga nasyonal kan asean na naglilimita sa mga entrada kada miyembro kan estado' | Predicted: Not Profane | True Label: 0
# Sentence: 'nagadan siya na tios na gayo sa sarong ospital sikyatriya' | Predicted: Not Profane | True Label: 0
# Sentence: 'napasairarom an filipinas sa espanya sa laog nin na taon kun sain pinagtratar kan mga espanyol an mga babayi sagkod lalaki sa maraot na paagi' | Predicted: Not Profane | True Label: 0
# Sentence: 'an mga mensahe poon hulyo sundo desyembre napublikar sa librong to the priests our ladys beloved sons' | Predicted: Not Profane | True Label: 0
# Sentence: 'nababang an cavite sa ng banwaan asin ng ciudad' | Predicted: Not Profane | True Label: 0
# Sentence: 'an hukon nag desisyon nin mas dakol pang pagkaaram sa mga akusasyon bago magpadagos' | Predicted: Not Profane | True Label: 0
# Sentence: 'poon abot ini man an nagpadrino sa wcw halloween havoc ppv na padalan na manonongod sa wrestling' | Predicted: Not Profane | True Label: 0
# Sentence: 'saro man siyang paralangoy asin parakawat nin hockey' | Predicted: Not Profane | True Label: 0
# Sentence: 'an iba pang species nageestar sa mga guang kan kahoy asin an mga sa daga nageestar sa irarom nin bungag na saindang kinakalot abot sa rarom na na metro pye' | Predicted: Not Profane | True Label: 0
# Sentence: 'proceedings of the asem workshop aquachallenge beijing china april' | Predicted: Not Profane | True Label: 0
# Sentence: 'si geronimo sa amay na edad nagbali sa manlainlain na kompetisyon nin pagkanta siring kan tuklas talino na pinadrinohan kan philippine long distance telephone company pldt' | Predicted: Not Profane | True Label: 0
# Sentence: 'parati an bhb o npa nagkokolekta nin buhis sa mga negosyong yaon sa lugar kun saen sinda nagooperar asin makusog' | Predicted: Not Profane | True Label: 0
# Sentence: 'importante an sili saka pamienta ta ini panghale kan garo mahangot na parong kan page' | Predicted: Not Profane | True Label: 0
# Sentence: 'may ibang genus kaini totoo arog kan sa oxygtrigona igwang kinukupsit na liwoy na napaludogludog sa kublit kan tawo' | Predicted: Not Profane | True Label: 0
# Sentence: 'hinali kaini an imahe ni jackson gikan sa pagigin ordinaryong aktres tanganing magkaigwa nin harder exterior and a rougher neck' | Predicted: Not Profane | True Label: 0
# Sentence: 'eliseo pajarong diego silang asin an ki lucino sacramentong florante at laura' | Predicted: Not Profane | True Label: 0
# Sentence: 'apat na klase nin mga monomerong nucleotide iyo an mga prekursor sa dna sagkod apat na manlainlain na monomerong an prekursor sa rna' | Predicted: Not Profane | True Label: 0
# Sentence: 'pigeksportar naman an manggang prutas na de lata kan dakul nang nasyon' | Predicted: Not Profane | True Label: 0
# Sentence: 'pigklasipikar an mga diyalektos bilan norteng kamayo asin sur kamayo ethnologue' | Predicted: Not Profane | True Label: 0
# Sentence: 'si ulrich ensingen o ensinger pebrero sarong aleman na arkitektong medieval' | Predicted: Not Profane | True Label: 0
# Sentence: 'an biograpiya ni bergreen marco polo from venice to xanadu ginigibong tampok na pelikula na binibidahan ni matt damon' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa enot na parte kan february nagpuon an exo sa pagpromotar kan sur na koreanong bado na tatak na kolon sport kun sain sinda naggibo nin komersyal para sa bagong pares nin sneakers na pinangaran sa saindang kolaborasyon movexo' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa kamawotan magtaong pagalingaling asin dagos pagpadangog asin pagparomdom sa publiko kan gayon kan mga kantang bikolnon an kasararoan nagpasale nin sarong konsyerto kan desyembre' | Predicted: Not Profane | True Label: 0
# Sentence: 'huli sa toltol na pagotob sa katongdan sa magian na disposiyon sa pakitrato asin simple asin banal na pamumuhay asin metikulosong pagreparo kan mga kasibotan sa saiyang paroko an papel niya sa simbahan nagin matagom' | Predicted: Not Profane | True Label: 0
# Sentence: 'an apg iii system kan klasipikasyon para sa angiosperms inaayon ini sa eurosids' | Predicted: Not Profane | True Label: 0
# Sentence: 'an mambog nauclea orientalis ingles leichhardt pine sarong tinanom na nagkakahoy' | Predicted: Not Profane | True Label: 0
# Sentence: 'an amerikanang parakanta asin kompositor na si halsey nagpaluwas nin studio albums extended plays na mga kanta kabali na an tolo bilang featured artist promotional singles asin music videos' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa university of the east nagtapos siya kan kursong geodetic engineering' | Predicted: Not Profane | True Label: 0
# Sentence: 'ikakaag an mga sangkap susog sa timplada asin pagkadakul kan sira' | Predicted: Not Profane | True Label: 0
# Sentence: 'sunod na millennium nasurat an mga pinakasoanoy na iskritura nin hinduismo' | Predicted: Not Profane | True Label: 0
# Sentence: 'si isabel nagadan katahawan kan' | Predicted: Not Profane | True Label: 0
# Sentence: 'siya naglipat sa kawat na weightlifting kan asin napangganahan niya an pilak sa world championships' | Predicted: Not Profane | True Label: 0
# Sentence: 'ikaw na nagtatanong tungkol sa amin kami ang nagtutulungan sa pagbabago ng pakikibaka' | Predicted: Not Profane | True Label: 0
# Sentence: 'nagkaigwa man sya nin interes sa deretsos kan mga babayi asin pigpanginutan an atlas project na nagiimbistigar sa solar na enerhiya' | Predicted: Not Profane | True Label: 0
# Sentence: 'pinagtandaan ni lisboa an mga pang' | Predicted: Not Profane | True Label: 0
# Sentence: 'igwng mga parasurt asn parasaligsg na nagsasbing bak siyang bikolano' | Predicted: Not Profane | True Label: 0
# Sentence: 'kan periodo na grabi an pagtios huli sa makuring depression maski pa siring si ina niya pirme man siyang natatawan balon asin panggarogastos sa bado asin pagruruluwas kan mga barkada' | Predicted: Not Profane | True Label: 0
# Sentence: 'surat na pinaluwas kan wuhan police bureau pinalis na pigmamandohan si li na pumundo magparapalakop nin mga huringhuding manongod sa sars pirmado ni li asin duwang opisyales kan pulis' | Predicted: Not Profane | True Label: 0
# Sentence: 'an paggogoti simpli mansanang prinipritos ini sa lana asin ta ini narulubag' | Predicted: Not Profane | True Label: 0
# Sentence: 'nagganap siya sa pelikulang roberta bilang sarong masungit na madrasta ni tessie aganas an titulo asin karakter kan pelikula dawa siya anyos pa sana' | Predicted: Not Profane | True Label: 0
# Sentence: 'naapektuhan an pagbirisita nin mga turista sa lugar nin huli sa bakong pusog na politikal na kamugtakan kan rehiyon asin an mga pagprobar na pagtanyog kaini kan dekada asin' | Predicted: Not Profane | True Label: 0
# Sentence: 'kaya kan desyembre sa rigon kan akta republika nu an naga nagin siyudad indepediente sa probinsya nin camarines sur' | Predicted: Not Profane | True Label: 0
# Sentence: 'si aguinaldo nagbalik sa pribado nang pamumuhay' | Predicted: Not Profane | True Label: 0
# Sentence: 'si wilkerson napangagom si gwendollyn rose gwen carosso kan' | Predicted: Not Profane | True Label: 0
# Sentence: 'nagluwas naman an saiyang tula sa liwayway magazinekalatasliteraryzine httpskalatasliteraryezine' | Predicted: Not Profane | True Label: 0
# Sentence: 'mayong pankagabsang pagtanggap an ainu sa panhenealokikal na relasyon sa arinman na iba pang pamilya nin tataramon' | Predicted: Not Profane | True Label: 0
# Sentence: 'mga burak na ipigbugtak sa parang kan estasyon nin rokujiz' | Predicted: Not Profane | True Label: 0
# Sentence: 'dakol kan mga sadiring tawo niya nagin mga prominente asin darakulang katungdan an kinarapotan' | Predicted: Not Profane | True Label: 0
# Sentence: 'si moreno saro sa doseng artistang ginana an apat na mayor na mga premyo sa lantad nin amerikanong entertainment egot oscar emmy grammy asin tony' | Predicted: Not Profane | True Label: 0
# Sentence: 'an artikulo pilmograpiya kan amerikanang aktres na si susan sarandon' | Predicted: Not Profane | True Label: 0
# Sentence: 'natapos niya an bachelor of laws komo salutatorian sa san beda college of law kan' | Predicted: Not Profane | True Label: 0
# Sentence: 'pagkatapos kan pageant nakamit niya an first runnerup ki michelle leonardo' | Predicted: Not Profane | True Label: 0
# Sentence: 'kan si madonna nagganap bilang breathless mahoney sa dick tracy na idinerekta ni warren beatty asin nakabase sa comic strip ni chester gould' | Predicted: Not Profane | True Label: 0
# Sentence: 'ini piglathala kan imangi studios sarong sequel kan orihinal kawat' | Predicted: Not Profane | True Label: 0
# Sentence: 'naalok siyang igdi na magtener asin kahurihan kaidto ginibo na siyang kura paroko asin vicar general kan diocesis' | Predicted: Not Profane | True Label: 0
# Sentence: 'an pinakmatuang texto kaini iyo an tolkapiyyam na puede ser na hali pa sa ikalimang siglo antes ni hesukristo' | Predicted: Not Profane | True Label: 0
# Sentence: 'an teritoryo kan isla nin pasko' | Predicted: Not Profane | True Label: 0
# Sentence: 'an kahoy kaining santol magayon na materyal sa konstruksyon huli ta dakul asin bakong maipo asin maray itrabaho ta bakong sobrang tagas saka magayon an supat' | Predicted: Not Profane | True Label: 0
# Sentence: 'provincial government of albay' | Predicted: Not Profane | True Label: 0
# Sentence: 'nakipagtabangan siya sa mga parasakop na briton na kunsaen piglaag siya bilang gobernador kan rehiyon ilocos sa saindang ngaran asin nangako nin pagpapakusog nin militarya tanganing tabang sa laban kontra sa mga espanyol' | Predicted: Not Profane | True Label: 0
# Sentence: 'an titulo kan program guno man sa tataramon na mati na an boot sabihon iyo an pagmamangno kan ano man na nasa luwas magin ini man kariribokan o lenggwahe' | Predicted: Not Profane | True Label: 0
# Sentence: 'si young nagpili nin duwa kan iba pang mga apostoles sinda heber c kimball asin willard richards bilang an saiyang mga tagapagpayo sa enot na panguluhan' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa bikol inaapod pa an sugok na bunay albay itlog rinconada salag miraya bunay' | Predicted: Not Profane | True Label: 0
# Sentence: 'dakulang utang na boot ki g fabiana arejola sa pagtugot na kuan retrato an lokd sa laog kan museo' | Predicted: Not Profane | True Label: 0
# Sentence: 'mga ehemplo kan kristiyanong relihiyosong mga bagay an banal na bibliya sarong krusipiko asin sarong rosaryohan' | Predicted: Not Profane | True Label: 0
# Sentence: 'siring man ini nahugas sa anoman na mga toxin sa hawak' | Predicted: Not Profane | True Label: 0
# Sentence: 'masikot asin mapagal intindihon an panlaog na kapormahan kan mga tataramon na austronesyo' | Predicted: Not Profane | True Label: 0
# Sentence: 'susog sa senso kan igwang katawo na nageerok igdi' | Predicted: Not Profane | True Label: 0
# Sentence: 'naghihingagdan na an ainu na hokkaido dawa magkapirang mga pigsagibo na gibuhon tanganing mabuhay ini' | Predicted: Not Profane | True Label: 0
# Sentence: 'kadaklan sa mga pangaran kan subanen subanon o subanun mantang an mga pigkaloob an sadiri sa islam pigtutukoy an saindang sadiri bilankalibugan' | Predicted: Not Profane | True Label: 0
# Sentence: 'an bansag saiyang koronel sa totoo bako man tunay na ranggo sa militar kundi apod sana saiya koronel man ngaya na tagakentucky' | Predicted: Not Profane | True Label: 0
# Sentence: 'mantang sa taon paitaas urog na dakol an kababaihan kun saen sinda minakompuesto ki porsyento para sa edad na iyan' | Predicted: Not Profane | True Label: 0
# Sentence: 'atubangan kan librong sucesos de las islas filipinas' | Predicted: Not Profane | True Label: 0
# Sentence: 'siya an sinasabing ama kan syensia sa kompyuter teoretiko asin sa inaapod na artificial intelligence' | Predicted: Not Profane | True Label: 0
# Sentence: 'igwa ining sukol na kilometro kwadrado na kadagaan asin namumugtak sa inot na distrito' | Predicted: Not Profane | True Label: 0
# Sentence: 'halimbaw an sarng persona iy an sentro nin pagaalap sa banggng iyn asn an saro man minatindg sa pagtang alap komo sa pagpasalamatpagumaw sa tao asn an ib man minaalap sa paguyon kan inot na nagtindg asn nagalap' | Predicted: Not Profane | True Label: 0
# Sentence: 'iba pang bitamina yaon sa dumang ini iyo an bitamina a bitamina bcomplex arog kan folates rikboflavin pantothenic acid asin thiamin' | Predicted: Not Profane | True Label: 0
# Sentence: 'siya an panduwang miyembro kan gabinete ni presidente rodrigo duterte na hinali kan commission on appointments sunod ki dating sekretarya kan department of foreign affairs na si perfecto yasay' | Predicted: Not Profane | True Label: 0
# Sentence: 'tomas asin nakapasar sa bar kan' | Predicted: Not Profane | True Label: 0
# Sentence: 'si lee minji pinangaki kan nobyembre sarong aktres sa south korea' | Predicted: Not Profane | True Label: 0
# Sentence: 'ginana niya an magkapirang titulong pangkinaban sa tolong magkakaibang kategorya nin timbang' | Predicted: Not Profane | True Label: 0
# Sentence: 'bilang tugma gamit ini sa seda koton asin wool' | Predicted: Not Profane | True Label: 0
# Sentence: 'kan si moon an solong naglaban sa parehas na season kan tribe of hip hop' | Predicted: Not Profane | True Label: 0
# Sentence: 'isinasaalangalang ni kaufman an kataga na cholo na malibog asin nagpapakumbaba' | Predicted: Not Profane | True Label: 0
# Sentence: 'si magahum an kagmukna kan pinakaenot na nobelang hiligaynon titulado benjamin na nasurat niya kan taon asin napublikar kan' | Predicted: Not Profane | True Label: 0
# Sentence: 'an relo sana may gabat na mga tonelada' | Predicted: Not Profane | True Label: 0
# Sentence: 'magkaag tubig sa kawali ikaag mga bawang sibulyas laya' | Predicted: Not Profane | True Label: 0
# Sentence: 'duwa o tolong kutsara na nasa kadikit na tubig an pigtatao' | Predicted: Not Profane | True Label: 0
# Sentence: 'kan nakamit niya an bagong rekord sa mga pinahalangkaw asin pinakahaloy na paglakaw sa tightrope' | Predicted: Not Profane | True Label: 0
# Sentence: 'si eleanor hallowell abbott mrs fordyce coburn setyembre june sarong binibistong awtor sa nasyon kan amerika' | Predicted: Not Profane | True Label: 0
# Sentence: 'dai man siya nanggana alagad huli sa pagkakabantog niya dakol an nagin alok na trabaho sa saiya sa modelling telebisyon asin pelikula' | Predicted: Not Profane | True Label: 0
# Sentence: 'sinasabi na an terminong balisong hale sa duwang kataga bali asin sungay na boot sabihon an mga bare nang sungoy damulag iyo an ginagamit sa pagpolo igdi' | Predicted: Not Profane | True Label: 0
# Sentence: 'igwang natatadang na aldaw sagkod kan katapusan nin taon' | Predicted: Not Profane | True Label: 0
# Sentence: 'an aspirin iyo nakakatabang para malikayan an atake sa puso ischaemic strokes asin pagbilog nin dugo sa mga tawong halangkaw an posibilidad na magkaigwa kaini' | Predicted: Not Profane | True Label: 0
# Sentence: 'nagsaro sinda nin na taon alagad dai sinda nagkaaki' | Predicted: Not Profane | True Label: 0
# Sentence: 'an nasyunal na akademya kan siyensya asin teknolohiya' | Predicted: Not Profane | True Label: 0
# Sentence: 'an movimientong ini pwede ser sanga mansana kan ideolohiyang sosyalista asin buminutwa sa mga lugar na dai kontento sa kamugtakan kan ekonomiya' | Predicted: Not Profane | True Label: 0
# Sentence: 'ini tinogdok kan sa gastos na pounds' | Predicted: Not Profane | True Label: 0
# Sentence: 'pigatendiran kan mga ministro hale sa doseng nasyun an miting natapos na naglalaom nin mga taunang miting sa futuro sa singapore asin sur na korea' | Predicted: Not Profane | True Label: 0
# Sentence: 'an saiyang elektra contract tinugutan an parakanta na magkaigwa in kontrol sa paggibo kan saiyang kanta sarong bagay na dai itinugot saiya kan siya nasa beverly glen' | Predicted: Not Profane | True Label: 0
# Sentence: 'an salang ginuhit risangrisa an kuko kumpara sa pinaolnok na liog' | Predicted: Not Profane | True Label: 0
# Sentence: 'an karera niya naglawig nang pitong polong taon sa mga maonabihan na trabaho niya iyo an papel niya pagsuporta sa mga pelikulang musikal na the king and i asin an west side story' | Predicted: Not Profane | True Label: 0
# Sentence: 'nanggana nin filmfare award for best female playback singer si mamta sharma para sa kantang ini mantang nanggana sina sajidwajid asin lalit pandit nin filmfare award for best music director sa th filmfare awards' | Predicted: Not Profane | True Label: 0
# Sentence: 'si ilarde nagadan kan agosto sa edad na huli sa kagurangan sa harong niya sa makati asin bako man huli sa covid paliwanag kan pamilya' | Predicted: Not Profane | True Label: 0
# Sentence: 'tanganing saiyang suportaran an saiyang pagako si rigdon pinagsabi an saiyang halawig na pakiibahan ki joseph smith asin sa katotohanan na siya sana an natatadang miyembro kan enot na panguluhan' | Predicted: Not Profane | True Label: 0
# Sentence: 'gikan sa taramon na hoyop na ang boot sabihon oyopan' | Predicted: Not Profane | True Label: 0
# Sentence: 'naglaog sia sa kuarto asin naghagad nin permiso sa huwes na sabihan sinda alagad isinikwal siya kan huwes' | Predicted: Not Profane | True Label: 0
# Sentence: 'sinbi niyng si perfecto iy an sar sa igwng pinakadakl na sinrat sa lokal na tatarmon sa panahn na pataps na an rehimen kastila' | Predicted: Not Profane | True Label: 0
# Sentence: 'an bulkan sarong paboritong lugar kan mga paratukad asin iyo an pinakatampok kan mount kanlaon natural park sarong pambawang parke na inot na iminukna kan agosto' | Predicted: Not Profane | True Label: 0
# Sentence: 'namundag sa katiosan an ama niya iyo si placido lopez na an trabaho parahirahay sana man kun anoano asin an ina niya si maria jacoba jaena sarong paratahi' | Predicted: Not Profane | True Label: 0
# Sentence: 'tolong estudyante man an nagadan sa busanga palawan pagkalamos sa sarong salog' | Predicted: Not Profane | True Label: 0
# Sentence: 'si belinda harrow namundag sarong saskatchewan na artistabiswal' | Predicted: Not Profane | True Label: 0
# Sentence: 'an magasin na forbes pigtatantya na an yaman na ni maezawa base ngonyan na bulan nin mayo nagaabot na sa net worth na billion asin siya an ikang mayamanon na persona sa hapon' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa bandang solnopan kan kinaban dakul kaining mga pagboot binungkal na o dai naman higot na pinapasunod' | Predicted: Not Profane | True Label: 0
# Sentence: 'sarong gurang na babae sinapod siya asin dinara siya sa pading agostino na idto binunyagan siya sa pangaran na pedro bukaneg' | Predicted: Not Profane | True Label: 0
# Sentence: 'an tropikong storm washi sa dagat sulu kan disyembre' | Predicted: Not Profane | True Label: 0
# Sentence: 'an terminong diyalekto kung minsan ay pinaghihigpitan tanganing matawan nin depinisyon na daiestandarteng pagkakalainlain partikular sa mga pagkakataon na bakong espesyalista asin mga tradisyon nin linggwistiko na bakong ingles' | Predicted: Not Profane | True Label: 0
# Sentence: 'an ngaran kontrobersyal na baluga na bakong magayon na pagladawan sa mga aeta' | Predicted: Not Profane | True Label: 0
# Sentence: 'bisto man ini sa apod na bicol express' | Predicted: Not Profane | True Label: 0
# Sentence: 'kan an mga bigilantes nagdesisyon na lagkitan asin barahiboan si smith sa omahan ni john johnson sa hiram ohio sainda man na pinaglagkitan asin pinagbarahiboan si rigdon' | Predicted: Not Profane | True Label: 0
# Sentence: 'kan agosto an munisipyo kan bakun asin ampusongan nagin parte na kan benguet na subprobinsya kan mt' | Predicted: Not Profane | True Label: 0
# Sentence: 'pirang bulan siya nagin receptionist sa sarong eskwelahan medikal tapos nagin siyang lab assistant asin modelo nin retratista na si heinrich hoffmann na natongod man iyo an retratista kan partido nazi' | Predicted: Not Profane | True Label: 0
# Sentence: 'nagin matriyumpo an saiyang karera kan para sa pelikulang satire na maps to the stars asin dramang still alice' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa pagalingaling siya mahusay magkanta asin magkawat sa ahedres mala ta kan medyo hubin pa siya nagbabali siya sa mga pakontes sa ahedres sa manila asin saiya na daang nadaog sa kawat si bantogan na parakawat chess na si florencio campones' | Predicted: Not Profane | True Label: 0
# Sentence: 'sa ultimong edisyon na ini saiyang itinolod an pagtubod na igwa kan sinasabing pagisog kan kadagaan kan mga kotinente sarong hipotesis na naprobaran na totoo pakalihis nin pirang siglo pa' | Predicted: Not Profane | True Label: 0
# Sentence: 'kan hunyo an presenteng tagapagpalagda kaini na si nilo p aureus sobrino kan kagmukna ibinangon liwat an peryodiko' | Predicted: Not Profane | True Label: 0
# Sentence: 'an bantog na prinsipyo na magbigay ng ayon sa kakayahan' | Predicted: Not Profane | True Label: 0
# Sentence: 'siya parte kan kabinete' | Predicted: Not Profane | True Label: 0
# Sentence: 'ini inaapod na ikawalo sa mga ngangalasan nin kinaban susog sa unesco bilang sarong world heritage site' | Predicted: Not Profane | True Label: 0
# Sentence: 'pwedeng si heneral po del pilar an nagrekomenda na tawan siya nin honoraryong titulo kan henerala' | Predicted: Not Profane | True Label: 0
# Sentence: 'sabay igdi nagtratrabaho pa siya komo escribiente sa district court asin bilang rightofway agent para sa el pasowhite oaks railway' | Predicted: Not Profane | True Label: 0
# Sentence: 'si lee sanghee lee nari pinangaki kan oktobre isarong aktres sa south korea' | Predicted: Not Profane | True Label: 0
# Sentence: 'an imahen ni seor sto' | Predicted: Not Profane | True Label: 0
# Sentence: 'pinangenotan nya an mga hukbo mgkapirang beses sa saiyang buhay asin lider kan ikaduwang krusada' | Predicted: Not Profane | True Label: 0
# Sentence: 'naenot na nagtreyning si iu sa good entertainment kaiba si uee yubin heo gayoon asin jun hyoseong' | Predicted: Not Profane | True Label: 0
# Sentence: 'an siisay man makatodas sa toro inaapod na maestro asin siya opisyal na binabansagan na matador de toros' | Predicted: Not Profane | True Label: 0
# Sentence: 'an alternatibong pangaran kaito iyo an iau bakong parehas sa tataramon na iau mantembu mora turu asin yapanani' | Predicted: Not Profane | True Label: 0
# Sentence: 'igwa ining sukol na kilometro kwadrado na kadagaan asin namumugtak sa solong distrito' | Predicted: Not Profane | True Label: 0
# Sentence: 'ini nasa porma nin sarong cassette tape' | Predicted: Not Profane | True Label: 0
# Sentence: 'an santuario ni san joseng patriarca na namomogtsak sa sentro saro sa popular na pilgramaheng sitio kan mga katoliko' | Predicted: Not Profane | True Label: 0
# Sentence: 'nakasali man si barbacena sa mga primerang tauhan sa sarong indie na pelikula na st ko si rd ini man an saiyang inot na pagluwas sa pelikula' | Predicted: Not Profane | True Label: 0
# Sentence: 'kun bibilangon pa ang iba pang naggagamit kan tataramon na ini masubra ini sa na milyon' | Predicted: Not Profane | True Label: 0
# Sentence: 'saro ini sa pinakabantog na mga kasong kriminal sa sueco kan saiyang panahon' | Predicted: Not Profane | True Label: 0
# Sentence: 'siya nagsurat nin mga sikat na libro sa kasaysayan asin sarong kolumnista sa magasin kan bbc history magazine' | Predicted: Not Profane | True Label: 0
# Sentence: 'tapos magguta nin niyog' | Predicted: Not Profane | True Label: 0
# Sentence: 'an kunab kaini mahamis o maalsom asin sa laog may pisog na kayumanggihon' | Predicted: Not Profane | True Label: 0
# Sentence: 'an kadagaan kan isla iyo pigbibilog nin harus basalt asin lava' | Predicted: Not Profane | True Label: 0
# Sentence: 'siya duwang beses nagserbi komo gobernador kan california poon sundo' | Predicted: Not Profane | True Label: 0
# Sentence: 'sunod sunod na an panatake ninda sa mga estasyon kan mga armadong kastila arog kan sa tabuco' | Predicted: Not Profane | True Label: 0
# ...
# Sentence: 'tian dakulon na itaram' | Predicted: Not Profane | True Label: 1
# Sentence: 'garo ka patal ade nata kaipuhan mo pa itong ipost papansin kang kupal ka' | Predicted: Profane | True Label: 1
# Sentence: 'dangag okay lang ito ang mahalaga tig buhay mo' | Predicted: Profane | True Label: 1
# Sentence: 'pag talaga nag face to face graduation ta ruluhuon ko ang mga tulak kaining mga tungag na ini' | Predicted: Not Profane | True Label: 1
# Sentence: 'tang gastos ko ngunyan na june' | Predicted: Not Profane | True Label: 1
# Sentence: 'gago tunay mananggad na sana ph na' | Predicted: Profane | True Label: 1
# Sentence: 'daeng aldaw na dae ako nabubua sa style kang lintian na ini' | Predicted: Profane | True Label: 1
# Sentence: 'may collaboration pang naganap bulini iba kana donny' | Predicted: Not Profane | True Label: 1
# Sentence: 'warang naghapot kang opinyon mong ulol ka' | Predicted: Profane | True Label: 1
# Sentence: 'huning meeting na ini pirmi na sana ipaurag ang payo ko deputa baad pedeng maging agom na sana' | Predicted: Profane | True Label: 1
# Sentence: 'bumalik kana sako lintian' | Predicted: Not Profane | True Label: 1
# Sentence: 'lininaniya ta dae ko na naman na bookmark' | Predicted: Not Profane | True Label: 1
# Sentence: 'minadakol talaga ang dangag pag labsok na' | Predicted: Profane | True Label: 1
# Sentence: 'wara na patal nabubua kana kang kabaklaan mong tian ka' | Predicted: Profane | True Label: 1
# Sentence: 'dipisilon mag review yudeputa' | Predicted: Profane | True Label: 1
# Sentence: 'hayop kamo aram na nindong uto uto ako' | Predicted: Profane | True Label: 1
# Sentence: 'saro kapang tangina ka masiramon kamong tuukon puta' | Predicted: Profane | True Label: 1
# Sentence: 'mahibi talaga akong tangina nindo' | Predicted: Profane | True Label: 1
# Sentence: 'nasupog daa ang ph army sa mga habo kang mandatory rotc mga ulol' | Predicted: Profane | True Label: 1
# Sentence: 'makauragon mag hiling na kdrama na buko surunod sunod puta kauragon' | Predicted: Profane | True Label: 1
# Sentence: 'hahahaha ako ngani ulol man giraray kay jeno' | Predicted: Profane | True Label: 1
# Sentence: 'yudeputa ka nata kapa inaki ni may mong tangina ka mahibugon ang pandok mong tarantado ka mag face reveal ka hayop ka' | Predicted: Profane | True Label: 1
# Sentence: 'an kupal ay kupal na talaga' | Predicted: Profane | True Label: 1
# Sentence: 'tanginang mga tanga ini makulugon na bitis ko puta kamo' | Predicted: Profane | True Label: 1
# Sentence: 'dae mi man kasalan na dipisilon ka magsabot eh yudepota' | Predicted: Profane | True Label: 1
# Sentence: 'gago anong wara haha teh dakulon ngane' | Predicted: Profane | True Label: 1
# Sentence: 'i dont like her personality bako teh tangina mo wara ka lang personality pakyu' | Predicted: Profane | True Label: 1
# Sentence: 'wara na ako sa mood puta kaya' | Predicted: Profane | True Label: 1
# Sentence: 'puta dakulon na dangag buda nagtthrow na naman' | Predicted: Profane | True Label: 1
# Sentence: 'pakshet ka talaga tito boyet nagkakaturulala na si max' | Predicted: Profane | True Label: 1
# Sentence: 'kusugon maka sanaol putangina kung nag ambag ka sana tangina mo ulol wara kang ambag puta maski sa pagkanta ako nagdara tangina mo ba imbis saimo na su verse na ito tangina yuck kaadirion ampota' | Predicted: Profane | True Label: 1
# Sentence: 'nagtatao lang gayod ki pakonswelo si robin kay patal ta may hilang na siya so sabuton ta na lang guna si robin' | Predicted: Profane | True Label: 1
# Sentence: 'igkukurab ako mga pakshet' | Predicted: Profane | True Label: 1
# Sentence: 'muay ko man sana bistuhon ki maray su jeong sa jeonghun kingina ngonyan lubog na lubog na ako sa kamember niya tangina' | Predicted: Profane | True Label: 1
# Sentence: 'wara talaga akong pake maski paghirilingon ako na naghihibi sa bus puta nahiling ko su igtutukawan mi ni ella sa moa' | Predicted: Profane | True Label: 1
# Sentence: 'kupal ini si neli guna lugod ninda bday ko haha' | Predicted: Profane | True Label: 1
# Sentence: 'gago pinutulan ki kamot katakot' | Predicted: Profane | True Label: 1
# Sentence: 'putangina miss ko na talaga siya' | Predicted: Profane | True Label: 1
# Sentence: 'tangina nindo tdg so ako sana talaga dae nakakalingaw kan rabas ta mga gago ba kamo' | Predicted: Profane | True Label: 1
# Sentence: 'harayuon na ang mga kupal' | Predicted: Profane | True Label: 1
# Sentence: 'huni pa saro ulol ka man ngane' | Predicted: Profane | True Label: 1
# Sentence: 'tangina patalon talaga ini ampota' | Predicted: Profane | True Label: 1
# Sentence: 'bawal an gago ka' | Predicted: Profane | True Label: 1
# Sentence: 'gago warang mailuwas na maski anong crreative juices ining pamayo ko' | Predicted: Profane | True Label: 1
# Sentence: 'dai taka man crush pucha ka' | Predicted: Profane | True Label: 1
# Sentence: 'tangina ano ining nag agi sa tl ko haha pucha' | Predicted: Profane | True Label: 1
# Sentence: 'gabos mananggad na jason sa mundo ay kabangagng patal buda kabangagng dangag' | Predicted: Profane | True Label: 1
# Sentence: 'nagbalik nanaman ang ulol niya na utak' | Predicted: Profane | True Label: 1
# Sentence: 'warang pagbabago ngane eh kupal parin talaga amski nuaren tangina kaining mga marketing staffs nila hugak hugakan eh' | Predicted: Profane | True Label: 1
# Sentence: 'bwiset talaga mga tawo digdi' | Predicted: Profane | True Label: 1
# Sentence: 'pogion si changbin putangina speechless ako duman ah' | Predicted: Profane | True Label: 1
# Sentence: 'pogion talaga si mark bwiset' | Predicted: Profane | True Label: 1
# Sentence: 'puta ka dai mo ba aram meaning ki bisexual di porket nag sa lalake straight na dai rin porket may type na sa lalaki straight na punyeta' | Predicted: Profane | True Label: 1
# Sentence: 'tarantado an wara na sa tamang pag isip' | Predicted: Profane | True Label: 1
# Sentence: 'tangina kakauli ko lang miss ko bns' | Predicted: Profane | True Label: 1
# Sentence: 'normal lang tabi ma ulol sa bako ta bias' | Predicted: Profane | True Label: 1
# Sentence: 'kulugon sa halunan pucha' | Predicted: Profane | True Label: 1
# Sentence: 'ben gago ka nata mo igdelete su file' | Predicted: Profane | True Label: 1
# Sentence: 'putangina nindo ako na sana kaya masapak saindo mga puta' | Predicted: Profane | True Label: 1
# Sentence: 'kukuwaon na kuta cp ko pero sabe ko igtext ko si mama na nawalat su payong sa harong tapos mauran na dae ko nakua eh haha pakshet matibayon talaga ako' | Predicted: Profane | True Label: 1
# Sentence: 'dipisilon pakihurunan pag igsingil puta mga kupal' | Predicted: Profane | True Label: 1
# Sentence: 'puta gayunon gabos dipisilon magpili kaya ilikom na sana gabos' | Predicted: Profane | True Label: 1
# Sentence: 'haha tarantado nahihiling kan tito ko notes ko puro confession para kay dagat' | Predicted: Profane | True Label: 1
# Sentence: 'huy gago may duplicate na si seungmin sa ako na an please' | Predicted: Profane | True Label: 1
# Sentence: 'putangina haha bwiset ka' | Predicted: Profane | True Label: 1
# Sentence: 'tangina talaga kan mga iresponsableng members kan research group dai sana maikaag name nindo sa final research paper putangina nindo' | Predicted: Profane | True Label: 1
# Sentence: 'hinayupak ka arturo makabwiseton kang pakshet ka' | Predicted: Profane | True Label: 1
# Sentence: 'ay pakshet nata wara ako' | Predicted: Profane | True Label: 1
# Sentence: 'dae ko igkakaraya haha oh its better to watch romantic drama para aram nindo kung pano mang kiss haha bwiset' | Predicted: Profane | True Label: 1
# Sentence: 'gago mamunduon an salubong' | Predicted: Profane | True Label: 1
# Sentence: 'patalon ka inutil warang modo tarantado siraulo animal' | Predicted: Profane | True Label: 1
# Sentence: 'warang ma amin putangina bako ini simbahan' | Predicted: Profane | True Label: 1
# Sentence: 'bwiset man ini gari daa ako indian' | Predicted: Profane | True Label: 1
# Sentence: 'inda ko kung matali pa ba ako o dangagon na ako' | Predicted: Profane | True Label: 1
# Sentence: 'pucha sabi ko ako man sanang solo naka isip' | Predicted: Profane | True Label: 1
# Sentence: 'ulol tangina mo bua' | Predicted: Profane | True Label: 1
# Sentence: 'aram mo ba tatapuson ko pa sana an kaso wara palan siya katapusan gago talaga' | Predicted: Profane | True Label: 1
# Sentence: 'su mga modules ko dae pa tapos sa june na pasahan punyeta' | Predicted: Profane | True Label: 1
# Sentence: 'makatakuton ka bwiset ka' | Predicted: Profane | True Label: 1
# Sentence: 'congrats sato gabos huhu months ako catch up ka miss you maski kupal kang malala' | Predicted: Profane | True Label: 1
# Sentence: 'ulukon ako sa cpar ko punyeta' | Predicted: Profane | True Label: 1
# Sentence: 'bwiset kaya mga scammers eh' | Predicted: Profane | True Label: 1
# Sentence: 'bwiset na restrictions sa facebook' | Predicted: Profane | True Label: 1
# Sentence: 'ano kaya muya mo bumagsak ministry kupal ka ba' | Predicted: Profane | True Label: 1
# Sentence: 'pakshet muya ko ki jollibee' | Predicted: Profane | True Label: 1
# Sentence: 'putangina ma angason vebs' | Predicted: Profane | True Label: 1
# Sentence: 'halat man kaya niki teka hoon ano ba xiaoting huhuh bwiset kayo ano ba pundo haha' | Predicted: Profane | True Label: 1
# Sentence: 'tangina tinatapos ko pa video ko para sa defense' | Predicted: Profane | True Label: 1
# Sentence: 'eto nanaman wara akong ginibo except magkaturog punyeta saro na sana kaya su assignment suhapon bilang nag daragdag' | Predicted: Profane | True Label: 1
# Sentence: 'sa inot man sana lugmok su binua mo pag naka bangon an patal ika an mahibi buda mahabol sa mag ina mo sa inot man sana maogma ta yaon pa su thrill' | Predicted: Profane | True Label: 1
# Sentence: 'kamo an may problema bako lizquen mga ulol' | Predicted: Profane | True Label: 1
# Sentence: 'gago yaon duman si niela for sure yaon din duman si tali gogo santino buda tito' | Predicted: Profane | True Label: 1
# Sentence: 'tarantado haluyon daa ako mag tipon ki items natutal arog kaito ta camper gabos puta edi tinadtad ko ki muda sa chat bo sa bwisit ka kung sisay pa su warang ambag siya pa su maribukon punyeta' | Predicted: Profane | True Label: 1
# Sentence: 'kupal amputa nag dadali dali masyado maglaog sa mrt' | Predicted: Profane | True Label: 1
# Sentence: 'gigibuhon na naman nindo akong akbit pakyu kamo haha' | Predicted: Profane | True Label: 1
# Sentence: 'gago ka sis sinagad mo naman an pagiging clown' | Predicted: Profane | True Label: 1
# Sentence: 'inda ko man daw sa sadiri ko punyeta moments' | Predicted: Profane | True Label: 1
# Sentence: 'initon tarantado gari nasa manila na ako' | Predicted: Profane | True Label: 1
# Sentence: 'makaturog na ako ta baka dae ako magimata punyeta' | Predicted: Profane | True Label: 1
# Sentence: 'patal igpa abot ni bakla buda kinaagahan dae na ako kinahuron tata tangina nindo ah' | Predicted: Profane | True Label: 1
# Sentence: 'muya ko mag unli wings pucha' | Predicted: Profane | True Label: 1
# Sentence: 'tangina mo gago guna ko masarado ka na naman' | Predicted: Profane | True Label: 1
# Sentence: 'tarantado ka ba igtapok ngane sinda sa hawaii buda kan nagadan su ina ni apo lakay dae na sinda tinugutan ni cory mag uli sa pinas anong nagtakas pinagsasabe mo sige hithit pa' | Predicted: Profane | True Label: 1
# Sentence: 'last na ito sarong direct message pa bahala kana talaga bwiseton ka' | Predicted: Profane | True Label: 1
# Sentence: 'punyeta na meta ini duwang account ko na restrict' | Predicted: Profane | True Label: 1
# Sentence: 'ulol pangiton ka deybid' | Predicted: Profane | True Label: 1
# Sentence: 'haha patalon talaga ako' | Predicted: Profane | True Label: 1
# Sentence: 'bako lang mga tugang ko marugado saimo pati mga pagtaraning ming harong igahanap ka gago' | Predicted: Profane | True Label: 1
# Sentence: 'si maeumi palan ito puta guna ko ayam kan mutual ko' | Predicted: Profane | True Label: 1
# Sentence: 'dai ako maka get over puta' | Predicted: Profane | True Label: 1
# Sentence: 'na bua na ito' | Predicted: Profane | True Label: 1
# Sentence: 'seramon panggigilan si hajime pogion puta' | Predicted: Profane | True Label: 1
# Sentence: 'tangina makulugon an payong ini bwiset' | Predicted: Profane | True Label: 1
# Sentence: 'oh talaga ba shermaine pakyu haha' | Predicted: Profane | True Label: 1
# Sentence: 'patal ka dae mo pwedeng turuan mag batok ang sarong ukay' | Predicted: Profane | True Label: 1
# Sentence: 'putangina warang makaturog sa aga na ang defense' | Predicted: Profane | True Label: 1
# Sentence: 'wara kamong pakinabang mga dangag tangina' | Predicted: Profane | True Label: 1
# Sentence: 'gago warang halong karaw mga pre luwas na kamong lamisa ta mahanda akong lenchon gago magayon su ending warang karaw' | Predicted: Profane | True Label: 1
# Sentence: 'huni na naman si puta bako ko na man ngani an kasalanan ta pirmi ako tama' | Predicted: Profane | True Label: 1
# Sentence: 'lintian na marupukon ko ining barkada' | Predicted: Not Profane | True Label: 1
# Sentence: 'tarantado talaga si stell haha nagiulukon ako' | Predicted: Profane | True Label: 1
# Sentence: 'ano na ang plano ma ikot ikot na sana kita pirmi deputa' | Predicted: Profane | True Label: 1
# Sentence: 'dae pa akong naglalangoy sulo na ako deputa' | Predicted: Profane | True Label: 1
# Sentence: 'nag itom na naman ako puta' | Predicted: Profane | True Label: 1
# Sentence: 'pakyu saindong duwa nata dare dakulaon ang dagit kaining babayi kay zuri' | Predicted: Profane | True Label: 1
# Sentence: 'hayop magiging stan account pa gayod ining dump account ko' | Predicted: Profane | True Label: 1
# Sentence: 'hobi dae mo sana ako napapaugma na papa ulol naman ako saimo' | Predicted: Profane | True Label: 1
# Sentence: 'pirmi kana sana arog kaan hayop dae kana nag bago' | Predicted: Profane | True Label: 1
# Sentence: 'mga dangag talaga an na dilawan na an' | Predicted: Profane | True Label: 1
# Sentence: 'kung arog sana kaito ang buhay tang siram' | Predicted: Not Profane | True Label: 1
# Sentence: 'ulol anong warang pinangaking dangag tangina mo nata test tube kang aki' | Predicted: Profane | True Label: 1
# Sentence: 'pakyu mga nagtuturong turon lason makagigilon kamo' | Predicted: Profane | True Label: 1
# Sentence: 'wara na habo ko na haha puta makaulokon' | Predicted: Profane | True Label: 1
# Sentence: 'kaya palan sensetibon ako ngunyan puta' | Predicted: Profane | True Label: 1
# Sentence: 'nagpabutla kaman giraray na buakanangshit ka pakyu' | Predicted: Profane | True Label: 1
# Sentence: 'tarantado talaga mga maestro mo' | Predicted: Profane | True Label: 1
# Sentence: 'puta anong ipad nag titipon akong pang bayad sa book signing hayop' | Predicted: Profane | True Label: 1
# Sentence: 'samo sana gayod warang internet kung iyo ma tulong aldaw na punyeta wara pa nanggad na taramon' | Predicted: Profane | True Label: 1
# Sentence: 'maray man ta nakaisip kapang umuling patal ka' | Predicted: Profane | True Label: 1
# Sentence: 'paruton ang hamag nadaog pa nanggad' | Predicted: Not Profane | True Label: 1
# Sentence: 'dae ka lamang mabisa sa gurang mong dangag ka' | Predicted: Profane | True Label: 1
# Sentence: 'tungagon ka talagang maray ade' | Predicted: Not Profane | True Label: 1
# Sentence: 'nahiling taka nadasmag patal hahaha' | Predicted: Profane | True Label: 1
# Sentence: 'nag purusngak lamang akong pucha kang nahiling ko' | Predicted: Profane | True Label: 1
# Sentence: 'nag duruman sa ilawod su mga aki pakshet binarayaan ako' | Predicted: Profane | True Label: 1
# Sentence: 'bwiset nagka parasa su mga ginibo ni may' | Predicted: Profane | True Label: 1
# Sentence: 'matabilon garo ayam na ulol' | Predicted: Profane | True Label: 1
# Sentence: 'nakatangko si pay mo duman sa duyan dangag kaya' | Predicted: Profane | True Label: 1
# Sentence: 'lininaniyang pakaurag kang uran kusog na daeng siring' | Predicted: Not Profane | True Label: 1
# Sentence: 'mapa iraya kita matangkong niyog dae ka mag dinangag' | Predicted: Not Profane | True Label: 1
#
# Evaluation Metrics:
# True Positives (TP): 479
# True Negatives (TN): 486
# False Positives (FP): 4
# False Negatives (FN): 45
# Accuracy: 0.9517
# Precision: 0.9917
# Recall: 0.9141
# F1 Score: 0.9513
